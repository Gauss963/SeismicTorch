# %%
import os
import glob
import random
import torch

from obspy import Stream
from obspy import read
from obspy.signal.trigger import classic_sta_lta

import numpy as np 
import scipy.signal as signal
import matplotlib.pyplot as plt

# %%
def scale_amplitude(data, rate):
    'Scale amplitude or waveforms'
    
    tmp = np.random.uniform(0, 1)
    if tmp < rate:
        data *= np.random.uniform(1, 3)
    elif tmp < 2*rate:
        data /= np.random.uniform(1, 3)
    return data

# %%
def shift_event(data, maxshift, rate, start, halfdim): 
    'Randomly rotate the array to shift the event location'
    
    if np.random.uniform(0, 1) < rate:
        start += int(np.random.uniform(-maxshift, maxshift))

    start = max(min(start, len(data[0]) - halfdim), halfdim)
    return data[:, start-halfdim:start + halfdim]

# %%
data_per_noise = 1

# %%
def get_trigger_sample_0(input_Stream, sta_window = 1, lta_window = 5, threshold = 3.01):

    for i in range(3):
        
        tr = input_Stream[i]

        # Apply STA/LTA trigger
        cft = classic_sta_lta(tr.data, int(sta_window * tr.stats.sampling_rate), int(lta_window * tr.stats.sampling_rate))
        
        trigger_samples_list = np.where(cft > threshold)[0]

        if len(trigger_samples_list) > 0:
            max_sta_lta_sample = trigger_samples_list[np.argmax(cft[trigger_samples_list])]
        else:
            max_sta_lta_sample = np.random.randint(len(tr.data))

    
    return max_sta_lta_sample

# %%
def get_trigger_sample(input_Stream, sta_window = 1, lta_window = 5, threshold = 3.01):

    comp_acc = np.sqrt(input_Stream[0].data**2 + input_Stream[1].data**2 + input_Stream[2].data**2)
    cft = classic_sta_lta(comp_acc, int(sta_window * input_Stream[0].stats.sampling_rate), int(lta_window * input_Stream[0].stats.sampling_rate))
    trigger_samples_list = np.where(cft > threshold)[0]

    if len(trigger_samples_list) > 0:
        max_sta_lta_sample = trigger_samples_list[np.argmax(cft[trigger_samples_list])]
    else:
        max_sta_lta_sample = np.random.randint(len(comp_acc))
    
    return max_sta_lta_sample

# %%
def process_obspy_stream(input_Stream):

    
    fsin = 100.0
    fsout = 40.0
    wlen = 2.0
    alpha = 0.05
    freq = 0.5
    maxshift = 80
    shift_event_r = 0.995
    # shift_event_r = 0.0

    dim = int(wlen * fsout)
    indim = int(fsin * wlen) // 2 


    input_Stream.detrend(type = "linear")
    input_Stream.taper(alpha)
    input_Stream.filter(type = "highpass", freq = freq)

    data = np.vstack([input_Stream[ii].data for ii in range(len(input_Stream))])
    data_list = []

    use_trigger_as_noise = True

    if use_trigger_as_noise:
        trigger_sample = get_trigger_sample(input_Stream)
        data_trigger = shift_event(data, maxshift, shift_event_r, trigger_sample, indim)
        data_trigger = signal.resample(data_trigger, dim, axis = -1)     
        data_trigger = data_trigger.transpose()
        data_list.append(data_trigger)

        for i in range(data_per_noise - 1):
            data_random = shift_event(data, maxshift, 0, int(np.random.uniform(data.shape[-1] * alpha, data.shape[-1] * (1 - alpha))), indim)
            data_random = signal.resample(data_random, dim, axis = -1)
            data_random = data_random.transpose()
            data_list.append(data_random)

    else:
        for i in range(data_per_noise):
            data_random = shift_event(data, maxshift, 0, int(np.random.uniform(data.shape[-1] * alpha, data.shape[-1] * (1 - alpha))), indim)
            data_random = signal.resample(data_random, dim, axis = -1)
            data_random = data_random.transpose()
            data_list.append(data_random)

    return data_list

# %%
stream_list = []
stream_list = []
QSIS_train_data_X = np.array([])
QSIS_train_data_list = []

# %%
datadir = './data_QSIS_Noise'
file_name_part = 'HLX'

sac_files_X = glob.glob(f'{datadir}/*{file_name_part}*.sac')
sac_files_Y = [s.replace('X', 'Y') for s in sac_files_X]
sac_files_Z = [s.replace('X', 'Z') for s in sac_files_X]

# %%
print(sac_files_X)
print(sac_files_Y)
print(sac_files_Z)
# Out:
# ['./data_QSIS_Noise/5AE98.TW..HLX.2023.07.17.00.37.42.sac', './data_QSIS_Noise/5ADEE.TW..HLX.2023.07.15.10.45.07.sac', './data_QSIS_Noise/5AF5C.TW..HLX.2023.07.23.12.33.31.sac', './data_QSIS_Noise/5AE29.TW..HLX.2023.07.07.18.40.33.sac', './data_QSIS_Noise/5AE29.TW..HLX.2023.07.17.11.05.56.sac', './data_QSIS_Noise/5AF5C.TW..HLX.2023.07.18.04.50.17.sac', './data_QSIS_Noise/5AF0F.TW..HLX.2023.07.06.07.33.04.sac', './data_QSIS_Noise/5AF48.TW..HLX.2023.07.03.02.04.04.sac', './data_QSIS_Noise/5AE21.TW..HLX.2023.07.05.05.48.19.sac', './data_QSIS_Noise/5AE29.TW..HLX.2023.07.06.17.25.01.sac', './data_QSIS_Noise/5AF1E.TW..HLX.2023.07.18.07.08.06.sac', './data_QSIS_Noise/5AE2C.TW..HLX.2023.07.24.03.07.06.sac', './data_QSIS_Noise/5AE98.TW..HLX.2023.07.09.05.46.04.sac', './data_QSIS_Noise/5AF8A.TW..HLX.2023.07.18.13.28.28.sac', './data_QSIS_Noise/5AE29.TW..HLX.2023.07.18.17.02.30.sac', './data_QSIS_Noise/5AE99.TW..HLX.2023.07.06.07.37.18.sac', './data_QSIS_Noise/5AE29.TW..HLX.2023.07.09.10.56.20.sac', './data_QSIS_Noise/5AF48.TW..HLX.2023.07.03.01.49.50.sac', './data_QSIS_Noise/5AE21.TW..HLX.2023.07.20.02.17.19.sac', './data_QSIS_Noise/5AE28.TW..HLX.2023.07.02.05.58.05.sac', './data_QSIS_Noise/5AE29.TW..HLX.2023.07.17.19.39.13.sac', './data_QSIS_Noise/5AF8A.TW..HLX.2023.07.20.14.42.04.sac', './data_QSIS_Noise/5AF30.TW..HLX.2023.07.20.02.12.03.sac', './data_QSIS_Noise/5AF8A.TW..HLX.2023.07.19.08.08.37.sac', './data_QSIS_Noise/5AE29.TW..HLX.2023.07.07.18.35.56.sac', './data_QSIS_Noise/5AF5C.TW..HLX.2023.07.18.01.34.10.sac', './data_QSIS_Noise/5AF5C.TW..HLX.2023.07.13.01.53.14.sac', './data_QSIS_Noise/5AE29.TW..HLX.2023.07.23.20.21.36.sac', './data_QSIS_Noise/5AF0F.TW..HLX.2023.07.06.07.23.28.sac', './data_QSIS_Noise/5AE98.TW..HLX.2023.07.12.10.27.31.sac', './data_QSIS_Noise/5AE29.TW..HLX.2023.07.09.15.03.13.sac', './data_QSIS_Noise/5AF5C.TW..HLX.2023.07.13.05.26.20.sac', './data_QSIS_Noise/5AF30.TW..HLX.2023.07.18.03.54.58.sac', './data_QSIS_Noise/5AE2C.TW..HLX.2023.07.14.11.08.40.sac', './data_QSIS_Noise/5AF30.TW..HLX.2023.07.20.03.23.40.sac', './data_QSIS_Noise/5AF0F.TW..HLX.2023.07.06.05.25.22.sac', './data_QSIS_Noise/5AE29.TW..HLX.2023.07.23.18.24.10.sac', './data_QSIS_Noise/5AF5C.TW..HLX.2023.07.17.22.47.03.sac', './data_QSIS_Noise/5AF0F.TW..HLX.2023.07.06.07.47.09.sac', './data_QSIS_Noise/5AE29.TW..HLX.2023.07.19.14.34.17.sac', './data_QSIS_Noise/5AE29.TW..HLX.2023.07.17.19.28.42.sac', './data_QSIS_Noise/5AF8A.TW..HLX.2023.07.14.03.31.12.sac', './data_QSIS_Noise/5AF5C.TW..HLX.2023.07.21.00.55.36.sac', './data_QSIS_Noise/5AFB5.TW..HLX.2023.07.13.12.55.11.sac', './data_QSIS_Noise/5AE98.TW..HLX.2023.07.08.03.54.07.sac', './data_QSIS_Noise/5AE29.TW..HLX.2023.07.10.19.19.48.sac', './data_QSIS_Noise/5AE90.TW..HLX.2023.07.07.03.58.41.sac', './data_QSIS_Noise/5AE1C.TW..HLX.2023.07.06.03.18.30.sac', './data_QSIS_Noise/5AE21.TW..HLX.2023.07.18.07.14.01.sac', './data_QSIS_Noise/5AFA8.TW..HLX.2023.07.10.06.58.39.sac', './data_QSIS_Noise/5AE29.TW..HLX.2023.07.12.21.45.48.sac', './data_QSIS_Noise/5AE29.TW..HLX.2023.07.10.15.17.05.sac', './data_QSIS_Noise/5AE28.TW..HLX.2023.07.21.04.12.33.sac', './data_QSIS_Noise/5AE29.TW..HLX.2023.07.13.19.06.28.sac', './data_QSIS_Noise/5AE29.TW..HLX.2023.07.05.20.31.15.sac', './data_QSIS_Noise/5AE29.TW..HLX.2023.07.20.12.28.41.sac', './data_QSIS_Noise/5AE73.TW..HLX.2023.07.06.02.50.28.sac', './data_QSIS_Noise/5AE29.TW..HLX.2023.07.22.18.44.44.sac', './data_QSIS_Noise/5AF30.TW..HLX.2023.07.20.00.28.57.sac', './data_QSIS_Noise/5AE29.TW..HLX.2023.07.09.18.37.16.sac', './data_QSIS_Noise/5AE29.TW..HLX.2023.07.09.22.01.42.sac', './data_QSIS_Noise/5AE29.TW..HLX.2023.07.19.19.58.47.sac', './data_QSIS_Noise/5AE29.TW..HLX.2023.07.22.18.34.04.sac', './data_QSIS_Noise/5AE99.TW..HLX.2023.07.07.07.48.31.sac', './data_QSIS_Noise/5AE29.TW..HLX.2023.07.23.20.47.10.sac', './data_QSIS_Noise/5AE70.TW..HLX.2023.07.14.19.00.01.sac', './data_QSIS_Noise/5AE29.TW..HLX.2023.07.09.13.36.46.sac', './data_QSIS_Noise/5AE29.TW..HLX.2023.07.22.14 ...
# ['./data_QSIS_Noise/5AE98.TW..HLY.2023.07.17.00.37.42.sac', './data_QSIS_Noise/5ADEE.TW..HLY.2023.07.15.10.45.07.sac', './data_QSIS_Noise/5AF5C.TW..HLY.2023.07.23.12.33.31.sac', './data_QSIS_Noise/5AE29.TW..HLY.2023.07.07.18.40.33.sac', './data_QSIS_Noise/5AE29.TW..HLY.2023.07.17.11.05.56.sac', './data_QSIS_Noise/5AF5C.TW..HLY.2023.07.18.04.50.17.sac', './data_QSIS_Noise/5AF0F.TW..HLY.2023.07.06.07.33.04.sac', './data_QSIS_Noise/5AF48.TW..HLY.2023.07.03.02.04.04.sac', './data_QSIS_Noise/5AE21.TW..HLY.2023.07.05.05.48.19.sac', './data_QSIS_Noise/5AE29.TW..HLY.2023.07.06.17.25.01.sac', './data_QSIS_Noise/5AF1E.TW..HLY.2023.07.18.07.08.06.sac', './data_QSIS_Noise/5AE2C.TW..HLY.2023.07.24.03.07.06.sac', './data_QSIS_Noise/5AE98.TW..HLY.2023.07.09.05.46.04.sac', './data_QSIS_Noise/5AF8A.TW..HLY.2023.07.18.13.28.28.sac', './data_QSIS_Noise/5AE29.TW..HLY.2023.07.18.17.02.30.sac', './data_QSIS_Noise/5AE99.TW..HLY.2023.07.06.07.37.18.sac', './data_QSIS_Noise/5AE29.TW..HLY.2023.07.09.10.56.20.sac', './data_QSIS_Noise/5AF48.TW..HLY.2023.07.03.01.49.50.sac', './data_QSIS_Noise/5AE21.TW..HLY.2023.07.20.02.17.19.sac', './data_QSIS_Noise/5AE28.TW..HLY.2023.07.02.05.58.05.sac', './data_QSIS_Noise/5AE29.TW..HLY.2023.07.17.19.39.13.sac', './data_QSIS_Noise/5AF8A.TW..HLY.2023.07.20.14.42.04.sac', './data_QSIS_Noise/5AF30.TW..HLY.2023.07.20.02.12.03.sac', './data_QSIS_Noise/5AF8A.TW..HLY.2023.07.19.08.08.37.sac', './data_QSIS_Noise/5AE29.TW..HLY.2023.07.07.18.35.56.sac', './data_QSIS_Noise/5AF5C.TW..HLY.2023.07.18.01.34.10.sac', './data_QSIS_Noise/5AF5C.TW..HLY.2023.07.13.01.53.14.sac', './data_QSIS_Noise/5AE29.TW..HLY.2023.07.23.20.21.36.sac', './data_QSIS_Noise/5AF0F.TW..HLY.2023.07.06.07.23.28.sac', './data_QSIS_Noise/5AE98.TW..HLY.2023.07.12.10.27.31.sac', './data_QSIS_Noise/5AE29.TW..HLY.2023.07.09.15.03.13.sac', './data_QSIS_Noise/5AF5C.TW..HLY.2023.07.13.05.26.20.sac', './data_QSIS_Noise/5AF30.TW..HLY.2023.07.18.03.54.58.sac', './data_QSIS_Noise/5AE2C.TW..HLY.2023.07.14.11.08.40.sac', './data_QSIS_Noise/5AF30.TW..HLY.2023.07.20.03.23.40.sac', './data_QSIS_Noise/5AF0F.TW..HLY.2023.07.06.05.25.22.sac', './data_QSIS_Noise/5AE29.TW..HLY.2023.07.23.18.24.10.sac', './data_QSIS_Noise/5AF5C.TW..HLY.2023.07.17.22.47.03.sac', './data_QSIS_Noise/5AF0F.TW..HLY.2023.07.06.07.47.09.sac', './data_QSIS_Noise/5AE29.TW..HLY.2023.07.19.14.34.17.sac', './data_QSIS_Noise/5AE29.TW..HLY.2023.07.17.19.28.42.sac', './data_QSIS_Noise/5AF8A.TW..HLY.2023.07.14.03.31.12.sac', './data_QSIS_Noise/5AF5C.TW..HLY.2023.07.21.00.55.36.sac', './data_QSIS_Noise/5AFB5.TW..HLY.2023.07.13.12.55.11.sac', './data_QSIS_Noise/5AE98.TW..HLY.2023.07.08.03.54.07.sac', './data_QSIS_Noise/5AE29.TW..HLY.2023.07.10.19.19.48.sac', './data_QSIS_Noise/5AE90.TW..HLY.2023.07.07.03.58.41.sac', './data_QSIS_Noise/5AE1C.TW..HLY.2023.07.06.03.18.30.sac', './data_QSIS_Noise/5AE21.TW..HLY.2023.07.18.07.14.01.sac', './data_QSIS_Noise/5AFA8.TW..HLY.2023.07.10.06.58.39.sac', './data_QSIS_Noise/5AE29.TW..HLY.2023.07.12.21.45.48.sac', './data_QSIS_Noise/5AE29.TW..HLY.2023.07.10.15.17.05.sac', './data_QSIS_Noise/5AE28.TW..HLY.2023.07.21.04.12.33.sac', './data_QSIS_Noise/5AE29.TW..HLY.2023.07.13.19.06.28.sac', './data_QSIS_Noise/5AE29.TW..HLY.2023.07.05.20.31.15.sac', './data_QSIS_Noise/5AE29.TW..HLY.2023.07.20.12.28.41.sac', './data_QSIS_Noise/5AE73.TW..HLY.2023.07.06.02.50.28.sac', './data_QSIS_Noise/5AE29.TW..HLY.2023.07.22.18.44.44.sac', './data_QSIS_Noise/5AF30.TW..HLY.2023.07.20.00.28.57.sac', './data_QSIS_Noise/5AE29.TW..HLY.2023.07.09.18.37.16.sac', './data_QSIS_Noise/5AE29.TW..HLY.2023.07.09.22.01.42.sac', './data_QSIS_Noise/5AE29.TW..HLY.2023.07.19.19.58.47.sac', './data_QSIS_Noise/5AE29.TW..HLY.2023.07.22.18.34.04.sac', './data_QSIS_Noise/5AE99.TW..HLY.2023.07.07.07.48.31.sac', './data_QSIS_Noise/5AE29.TW..HLY.2023.07.23.20.47.10.sac', './data_QSIS_Noise/5AE70.TW..HLY.2023.07.14.19.00.01.sac', './data_QSIS_Noise/5AE29.TW..HLY.2023.07.09.13.36.46.sac', './data_QSIS_Noise/5AE29.TW..HLY.2023.07.22.14 ...
# ['./data_QSIS_Noise/5AE98.TW..HLZ.2023.07.17.00.37.42.sac', './data_QSIS_Noise/5ADEE.TW..HLZ.2023.07.15.10.45.07.sac', './data_QSIS_Noise/5AF5C.TW..HLZ.2023.07.23.12.33.31.sac', './data_QSIS_Noise/5AE29.TW..HLZ.2023.07.07.18.40.33.sac', './data_QSIS_Noise/5AE29.TW..HLZ.2023.07.17.11.05.56.sac', './data_QSIS_Noise/5AF5C.TW..HLZ.2023.07.18.04.50.17.sac', './data_QSIS_Noise/5AF0F.TW..HLZ.2023.07.06.07.33.04.sac', './data_QSIS_Noise/5AF48.TW..HLZ.2023.07.03.02.04.04.sac', './data_QSIS_Noise/5AE21.TW..HLZ.2023.07.05.05.48.19.sac', './data_QSIS_Noise/5AE29.TW..HLZ.2023.07.06.17.25.01.sac', './data_QSIS_Noise/5AF1E.TW..HLZ.2023.07.18.07.08.06.sac', './data_QSIS_Noise/5AE2C.TW..HLZ.2023.07.24.03.07.06.sac', './data_QSIS_Noise/5AE98.TW..HLZ.2023.07.09.05.46.04.sac', './data_QSIS_Noise/5AF8A.TW..HLZ.2023.07.18.13.28.28.sac', './data_QSIS_Noise/5AE29.TW..HLZ.2023.07.18.17.02.30.sac', './data_QSIS_Noise/5AE99.TW..HLZ.2023.07.06.07.37.18.sac', './data_QSIS_Noise/5AE29.TW..HLZ.2023.07.09.10.56.20.sac', './data_QSIS_Noise/5AF48.TW..HLZ.2023.07.03.01.49.50.sac', './data_QSIS_Noise/5AE21.TW..HLZ.2023.07.20.02.17.19.sac', './data_QSIS_Noise/5AE28.TW..HLZ.2023.07.02.05.58.05.sac', './data_QSIS_Noise/5AE29.TW..HLZ.2023.07.17.19.39.13.sac', './data_QSIS_Noise/5AF8A.TW..HLZ.2023.07.20.14.42.04.sac', './data_QSIS_Noise/5AF30.TW..HLZ.2023.07.20.02.12.03.sac', './data_QSIS_Noise/5AF8A.TW..HLZ.2023.07.19.08.08.37.sac', './data_QSIS_Noise/5AE29.TW..HLZ.2023.07.07.18.35.56.sac', './data_QSIS_Noise/5AF5C.TW..HLZ.2023.07.18.01.34.10.sac', './data_QSIS_Noise/5AF5C.TW..HLZ.2023.07.13.01.53.14.sac', './data_QSIS_Noise/5AE29.TW..HLZ.2023.07.23.20.21.36.sac', './data_QSIS_Noise/5AF0F.TW..HLZ.2023.07.06.07.23.28.sac', './data_QSIS_Noise/5AE98.TW..HLZ.2023.07.12.10.27.31.sac', './data_QSIS_Noise/5AE29.TW..HLZ.2023.07.09.15.03.13.sac', './data_QSIS_Noise/5AF5C.TW..HLZ.2023.07.13.05.26.20.sac', './data_QSIS_Noise/5AF30.TW..HLZ.2023.07.18.03.54.58.sac', './data_QSIS_Noise/5AE2C.TW..HLZ.2023.07.14.11.08.40.sac', './data_QSIS_Noise/5AF30.TW..HLZ.2023.07.20.03.23.40.sac', './data_QSIS_Noise/5AF0F.TW..HLZ.2023.07.06.05.25.22.sac', './data_QSIS_Noise/5AE29.TW..HLZ.2023.07.23.18.24.10.sac', './data_QSIS_Noise/5AF5C.TW..HLZ.2023.07.17.22.47.03.sac', './data_QSIS_Noise/5AF0F.TW..HLZ.2023.07.06.07.47.09.sac', './data_QSIS_Noise/5AE29.TW..HLZ.2023.07.19.14.34.17.sac', './data_QSIS_Noise/5AE29.TW..HLZ.2023.07.17.19.28.42.sac', './data_QSIS_Noise/5AF8A.TW..HLZ.2023.07.14.03.31.12.sac', './data_QSIS_Noise/5AF5C.TW..HLZ.2023.07.21.00.55.36.sac', './data_QSIS_Noise/5AFB5.TW..HLZ.2023.07.13.12.55.11.sac', './data_QSIS_Noise/5AE98.TW..HLZ.2023.07.08.03.54.07.sac', './data_QSIS_Noise/5AE29.TW..HLZ.2023.07.10.19.19.48.sac', './data_QSIS_Noise/5AE90.TW..HLZ.2023.07.07.03.58.41.sac', './data_QSIS_Noise/5AE1C.TW..HLZ.2023.07.06.03.18.30.sac', './data_QSIS_Noise/5AE21.TW..HLZ.2023.07.18.07.14.01.sac', './data_QSIS_Noise/5AFA8.TW..HLZ.2023.07.10.06.58.39.sac', './data_QSIS_Noise/5AE29.TW..HLZ.2023.07.12.21.45.48.sac', './data_QSIS_Noise/5AE29.TW..HLZ.2023.07.10.15.17.05.sac', './data_QSIS_Noise/5AE28.TW..HLZ.2023.07.21.04.12.33.sac', './data_QSIS_Noise/5AE29.TW..HLZ.2023.07.13.19.06.28.sac', './data_QSIS_Noise/5AE29.TW..HLZ.2023.07.05.20.31.15.sac', './data_QSIS_Noise/5AE29.TW..HLZ.2023.07.20.12.28.41.sac', './data_QSIS_Noise/5AE73.TW..HLZ.2023.07.06.02.50.28.sac', './data_QSIS_Noise/5AE29.TW..HLZ.2023.07.22.18.44.44.sac', './data_QSIS_Noise/5AF30.TW..HLZ.2023.07.20.00.28.57.sac', './data_QSIS_Noise/5AE29.TW..HLZ.2023.07.09.18.37.16.sac', './data_QSIS_Noise/5AE29.TW..HLZ.2023.07.09.22.01.42.sac', './data_QSIS_Noise/5AE29.TW..HLZ.2023.07.19.19.58.47.sac', './data_QSIS_Noise/5AE29.TW..HLZ.2023.07.22.18.34.04.sac', './data_QSIS_Noise/5AE99.TW..HLZ.2023.07.07.07.48.31.sac', './data_QSIS_Noise/5AE29.TW..HLZ.2023.07.23.20.47.10.sac', './data_QSIS_Noise/5AE70.TW..HLZ.2023.07.14.19.00.01.sac', './data_QSIS_Noise/5AE29.TW..HLZ.2023.07.09.13.36.46.sac', './data_QSIS_Noise/5AE29.TW..HLZ.2023.07.22.14 ...

# %%
for i in range(len(sac_files_X)):
    stream = Stream()
    st = read(sac_files_X[i])
    stream += st

    st = read(sac_files_Y[i])
    stream += st

    st = read(sac_files_Z[i])
    stream += st

    stream_list.append(stream)

# %%
for i in range(len(stream_list)):

    QSIS_train_data_list_append = process_obspy_stream(stream_list[i])

    for i in range(len(QSIS_train_data_list_append)):
        QSIS_train_data_list.append(QSIS_train_data_list_append[i])

# %%
QSIS_train_data_X = np.stack(QSIS_train_data_list)
QSIS_train_data_X = np.expand_dims(QSIS_train_data_X, axis = -1)

# %%
initial_array = np.array([[0., 0., 1.]])
QSIS_train_data_Y = np.tile(initial_array, (len(stream_list) * data_per_noise, 1))

print(QSIS_train_data_X.shape)
print(QSIS_train_data_Y.shape)
# Out:
# (725, 80, 3, 1)
# (725, 3)

# %%
torch.save({'Xnoise': QSIS_train_data_X, 'Ynoise': QSIS_train_data_Y}, './data_QSIS_pth/noise.pth')

# %%
datadir = './data_QSIS_pth'

train_data_path = os.path.join(datadir, 'noise.pth')
train_data = torch.load(train_data_path)
Xnoise = train_data['Xnoise']
Ynoise = train_data['Ynoise']

print(Xnoise.shape)
print(Ynoise.shape)
# Out:
# (725, 80, 3, 1)
# (725, 3)

# %%
print(len(stream_list) * data_per_noise)
# Out:
# 725

# %%
def plot_all_noise():
    plot_number = len(stream_list)
    # plot_number = 3

    alpha = 0.05
    freq = 0.5

    for i in range(plot_number):
        check_stream = stream_list[i]

        check_stream.detrend(type = "linear")
        check_stream.taper(alpha)
        check_stream.filter(type = "highpass", freq = freq)

        check_stream.plot(color = 'C0')
        print(check_stream)
