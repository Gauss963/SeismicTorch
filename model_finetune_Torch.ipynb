# %%
import copy
import torch
import time
import os

import torch.optim as optim
import torch.nn as nn
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from torch.utils.data import DataLoader
from torch.utils.data import Dataset
from torch.optim import lr_scheduler
from sklearn.metrics import confusion_matrix
from sklearn.model_selection import train_test_split
from def_model import EarthquakeCNN

import functions

# %%
class EarthquakeDataset(Dataset):
    def __init__(self, features, labels):
        self.features = features
        self.labels = labels

    def __len__(self):
        return len(self.features)

    def __getitem__(self, idx):
        return self.features[idx], self.labels[idx]

# %%
datadir = './data_QSIS_pth'

train_data_path = os.path.join(datadir, "all_merged.pth")
train_data = torch.load(train_data_path)
Xall = train_data['Xall']
Yall = train_data['Yall']

# %%
Xall, Yall = functions.remove_small_amplitude(Xall, Yall) 
Xall, Yall = functions.remove_large_amplitude(Xall, Yall)
log10_amplitude = np.log10(np.max(np.abs(Xall), axis = (1, 2, 3)))
Xall = functions.normalize(Xall)
Xall = functions.quantize(Xall)
Xall = Xall.astype(np.float32)
Xall = functions.normalize(Xall)

# %%
Xall = torch.from_numpy(Xall).float()
Yall = torch.from_numpy(Yall).float()

Xall = Xall.permute(0, 3, 1, 2)

# %%
# split the data into training and validation datasets
X_train, X_val, Y_train, Y_val = train_test_split(Xall, Yall, test_size = 0.2, random_state = 42)

# create datasets
train_dataset = EarthquakeDataset(X_train, Y_train)
val_dataset = EarthquakeDataset(X_val, Y_val)

# create dataloaders
train_dataloader = DataLoader(train_dataset, batch_size = 32, shuffle = True)
val_dataloader = DataLoader(val_dataset, batch_size = 32, shuffle = True)

# put dataloaders into a dictionary
dataloaders = {
    'train': train_dataloader,
    'val': val_dataloader
}

# similarly, create a dictionary for dataset sizes
dataset_sizes = {
    'train': len(train_dataset),
    'val': len(val_dataset)
}

# %%
print(X_train.shape)
print(Y_train.shape)
# Out:
# torch.Size([1328, 1, 80, 3])
# torch.Size([1328, 3])

# %%
class MyModel:
    def __init__(self, model, epoch_arr, train_loss_arr, val_loss_arr, train_acc_arr, val_acc_arr, lr_arr, cm, best_acc):
        self.model = model
        self.epoch_arr = epoch_arr
        self.train_loss_arr = train_loss_arr
        self.val_loss_arr = val_loss_arr
        self.train_acc_arr = train_acc_arr
        self.val_acc_arr = val_acc_arr
        self.lr_arr = lr_arr
        self.cm = cm
        self.best_acc = best_acc

# %%
def plot_loss_with_MyModel(MyModel_here, plot_title = "Default"):
    epoch_arr_here = MyModel_here.epoch_arr
    train_loss_arr_here = MyModel_here.train_loss_arr
    val_loss_arr_here = MyModel_here.val_loss_arr
    train_acc_arr_here = MyModel_here.train_acc_arr
    val_acc_arr_here = MyModel_here.val_acc_arr
    lr_arr_here = MyModel_here.lr_arr

    fig_loss_func, axes_loss_func = plt.subplots(nrows = 1, ncols = 3, figsize = (24, 6))
    fig_loss_func.suptitle(plot_title)

    axes_loss_func[0].plot(epoch_arr_here, train_loss_arr_here, label = 'Training Loss')
    axes_loss_func[0].plot(epoch_arr_here, val_loss_arr_here, label = 'Validation Loss')
    axes_loss_func[0].set_title('Loss')
    axes_loss_func[0].set_xlabel('Epoch')
    axes_loss_func[0].set_ylabel('Loss')
    axes_loss_func[0].legend()
    axes_loss_func[1].plot(epoch_arr_here, train_acc_arr_here, label = 'Training Accuracy')
    axes_loss_func[1].plot(epoch_arr_here, val_acc_arr_here, label = 'Validation Accuracy')
    axes_loss_func[1].set_title('Accuracy')
    axes_loss_func[1].set_xlabel('Epoch')
    axes_loss_func[1].set_ylabel('Accurracy')
    axes_loss_func[1].legend()
    axes_loss_func[2].plot(epoch_arr_here, lr_arr_here, label = 'Learning Rate')
    axes_loss_func[2].set_title('Learning Rate')
    axes_loss_func[2].set_xlabel('Epoch')
    axes_loss_func[2].set_ylabel('Accuracy')
    axes_loss_func[2].legend()
    fig_loss_func.tight_layout()
    plt.savefig('./Result_Finetuing/Accurracy.pdf')

# %%
def plot_cm_with_MyModel(MyModel_here, plot_title = "Default"):

    cm_here = MyModel_here.cm
    cm_here = cm_here.astype('float') / cm_here.sum(axis = 1)[:, np.newaxis]

    labels = ['P-wave', 'S-wave', 'Noise']
    cm_here_df = pd.DataFrame(cm_here, index = labels, columns = labels)
    cm_here = cm_here_df

    fig_cm_func, axes_cm_func = plt.subplots(nrows = 1, ncols = 1, figsize = (8, 6))
    acc_here = MyModel_here.best_acc.detach().cpu().numpy() * 100
    acc_here = round(acc_here, 2)
    fig_cm_func.suptitle(plot_title + ' Confusion Matrix, Accuracy = ' + str(acc_here) + '%')

    sns.heatmap(cm_here, annot = True, cmap = 'Blues', ax = axes_cm_func)
    axes_cm_func.set_title('Train Confusion Matrix')
    axes_cm_func.set_xlabel('Predicted Labels')
    axes_cm_func.set_ylabel('Actual Labels')
    fig_cm_func.tight_layout()

    plt.savefig('./Result_Finetuing/Confusion_Matrix.pdf')

# %%
def train_model(model, criterion, optimizer, scheduler, num_epochs = 25):
    since = time.time()

    best_model_wts = copy.deepcopy(model.state_dict())
    best_acc = 0.0

    epoch_arr = np.array([])
    lr_arr = np.array([])
    train_loss_arr = np.array([])
    train_acc_arr = np.array([])

    val_loss_arr = np.array([])
    val_acc_arr = np.array([])

    for epoch in range(num_epochs):
        print(f'Epoch {epoch}/{num_epochs - 1}')
        print('-' * 10)

        # Each epoch has a training and validation phase
        for phase in ['train', 'val']:
            if phase == 'train':
                model.train()  # Set model to training mode
            else:
                model.eval()   # Set model to evaluate mode

            running_loss = 0.0
            running_corrects = 0

            # These lists will hold all labels and predictions for this epoch
            # all_labels = []
            # all_preds = []

            all_labels = np.array([])
            all_preds = np.array([])

            # Iterate over data.
            for inputs, labels in dataloaders[phase]:
                inputs = inputs
                labels = labels

                # zero the parameter gradients
                optimizer.zero_grad()

                # forward
                # track history if only in train
                with torch.set_grad_enabled(phase == 'train'):
                    outputs = model(inputs)
                    _, preds = torch.max(outputs, 1)
                    _, labels = torch.max(labels.data, 1)
                    loss = criterion(outputs, labels)

                    # backward + optimize only if in training phase
                    if phase == 'train':
                        loss.backward()
                        optimizer.step()

                # statistics
                running_loss += loss.item() * inputs.size(0)
                running_corrects += torch.sum(preds == labels.data)

                # Add current labels and predictions to the lists
                # all_labels.extend(labels.tolist())
                # all_preds.extend(preds.tolist())

                all_labels = np.append(all_labels, labels.tolist())
                all_preds = np.append(all_preds, preds.tolist())

            if phase == 'train':
                scheduler.step()

            epoch_loss = running_loss / dataset_sizes[phase]
            epoch_acc = running_corrects / dataset_sizes[phase]

            print(f'{phase} Loss: {epoch_loss:.4f} Acc: {epoch_acc:.4f}')

            # After each epoch, compute and print the confusion matrix
            if phase == 'val':
                print("Confusion Matrix:")
                cm_here = confusion_matrix(all_labels, all_preds)
                print(cm_here)

            # save the loss and accurracy
            if phase == 'train':
                train_loss_arr = np.append(train_loss_arr, epoch_loss)
                train_acc_arr = np.append(train_acc_arr, epoch_acc.detach().cpu())
                lr_arr = np.append(lr_arr, optimizer.param_groups[0]['lr'])
                epoch_arr = np.append(epoch_arr, epoch)
            elif phase == 'val':
                val_loss_arr = np.append(val_loss_arr, epoch_loss)
                val_acc_arr = np.append(val_acc_arr, epoch_acc.detach().cpu())

            # deep copy the model
            if phase == 'val' and epoch_acc > best_acc:
                best_acc = epoch_acc
                best_model_wts = copy.deepcopy(model.state_dict())

    time_elapsed = time.time() - since
    print(f'Training complete in {time_elapsed // 60:.0f}m {time_elapsed % 60:.0f}s')
    print(f'Best val Acc: {best_acc:4f}')

    # load best model weights
    model.load_state_dict(best_model_wts)

    model_class = MyModel(model = model, 
                          epoch_arr = epoch_arr, 
                          train_loss_arr = train_loss_arr, 
                          val_loss_arr = val_loss_arr, 
                          train_acc_arr = train_acc_arr, 
                          val_acc_arr = val_acc_arr, 
                          lr_arr = lr_arr, 
                          cm = cm_here, 
                          best_acc = best_acc)

    return model_class

# %%
model = torch.load('./model/EarthquakeCNN.pth')
# model = EarthquakeCNN()

# 凍結模型的卷積層
for param in model.parameters():
    # param.requires_grad = False
    param.requires_grad = True

# 全連接層的權重將被更新
for param in model.fc1.parameters():
    param.requires_grad = True
for param in model.fc2.parameters():
    param.requires_grad = True
for param in model.fc3.parameters():
    param.requires_grad = True

# %%
criterion = nn.CrossEntropyLoss()

# 使用Adam優化器，並且設定學習率為0.001
# optimizer = optim.Adam(model.parameters(), lr = 0.001)
optimizer = optim.AdamW(model.parameters(), lr = 0.001)
# optimizer = optim.RAdam(model.parameters(), lr = 0.001)

# 每7個epoch，學習率減半
exp_lr_scheduler = lr_scheduler.StepLR(optimizer, step_size = 7, gamma = 0.5)

# %%
finetuned_MyModel = train_model(model, criterion, optimizer, exp_lr_scheduler, num_epochs = 100)
# Out:
# Epoch 0/99
# ----------
# train Loss: 1.6827 Acc: 0.4571
# val Loss: 0.8646 Acc: 0.5392
# Confusion Matrix:
# [[49 34 20]
#  [42 43 13]
#  [31 13 87]]
# Epoch 1/99
# ----------
# train Loss: 0.8485 Acc: 0.5678
# val Loss: 0.7648 Acc: 0.6084
# Confusion Matrix:
# [[ 37  46  20]
#  [ 25  55  18]
#  [  5  16 110]]
# Epoch 2/99
# ----------
# train Loss: 0.7595 Acc: 0.6295
# val Loss: 0.6897 Acc: 0.6476
# Confusion Matrix:
# [[ 40  45  18]
#  [ 35  51  12]
#  [  7   0 124]]
# Epoch 3/99
# ----------
# train Loss: 0.6958 Acc: 0.6627
# val Loss: 0.6478 Acc: 0.6898
# Confusion Matrix:
# [[ 51  37  15]
#  [ 35  55   8]
#  [  8   0 123]]
# Epoch 4/99
# ----------
# train Loss: 0.6598 Acc: 0.6852
# val Loss: 0.6163 Acc: 0.6747
# Confusion Matrix:
# [[ 47  36  20]
#  [ 38  52   8]
#  [  5   1 125]]
# Epoch 5/99
# ----------
# train Loss: 0.5974 Acc: 0.7093
# val Loss: 0.5892 Acc: 0.7139
# Confusion Matrix:
# [[ 60  33  10]
#  [ 37  57   4]
#  [  7   4 120]]
# Epoch 6/99
# ----------
# train Loss: 0.5725 Acc: 0.7206
# val Loss: 0.5856 Acc: 0.7108
# Confusion Matrix:
# [[ 57  31  15]
#  [ 36  54   8]
#  [  6   0 125]]
# Epoch 7/99
# ----------
# train Loss: 0.5359 Acc: 0.7477
# val Loss: 0.5664 Acc: 0.7048
# Confusion Matrix:
# [[ 54  40   9]
#  [ 36  58   4]
#  [  6   3 122]]
# Epoch 8/99
# ----------
# train Loss: 0.5375 Acc: 0.7455
# val Loss: 0.5618 Acc: 0.7048
# Confusion Matrix:
# [[ 54  34  15]
#  [ 38  55   5]
#  [  3   3 125]]
# Epoch 9/99
# ----------
# train Loss: 0.5194 Acc: 0.7643
# val Loss: 0.5524 Acc: 0.7199
# Confusion Matrix:
# [[ 58  39   6]
#  [ 36  58   4]
#  [  4   4 123]]
# Epoch 10/99
# ----------
# train Loss: 0.4895 Acc: 0.7771
# val Loss: 0.5635 Acc: 0.7139
# Confusion Matrix:
# [[ 63  29  11]
#  [ 43  50   5]
#  [  6   1 124]]
# Epoch 11/99
# ----------
# train Loss: 0.4838 Acc: 0.7786
# val Loss: 0.5648 Acc: 0.7018
# Confusion Matrix:
# [[ 56  41   6]
#  [ 37  57   4]
#  [  5   6 120]]
# Epoch 12/99
# ----------
# train Loss: 0.4856 Acc: 0.7636
# val Loss: 0.5537 Acc: 0.7169
# Confusion Matrix:
# [[ 51  46   6]
#  [ 28  66   4]
#  [  5   5 121]]
# Epoch 13/99
# ----------
# train Loss: 0.4519 Acc: 0.8035
# val Loss: 0.5707 Acc: 0.6928
# Confusion Matrix:
# [[ 50  50   3]
#  [ 33  62   3]
#  [  7   6 118]]
# Epoch 14/99
# ----------
# train Loss: 0.4464 Acc: 0.7884
# val Loss: 0.5527 Acc: 0.6988
# Confusion Matrix:
# [[ 50  46   7]
#  [ 35  58   5]
#  [  4   3 124]]
# Epoch 15/99
# ----------
# train Loss: 0.4323 Acc: 0.8080
# val Loss: 0.5500 Acc: 0.7199
# Confusion Matrix:
# [[ 56  43   4]
#  [ 32  61   5]
#  [  5   4 122]]
# Epoch 16/99
# ----------
# train Loss: 0.4265 Acc: 0.7997
# val Loss: 0.5519 Acc: 0.7018
# Confusion Matrix:
# [[ 53  46   4]
#  [ 34  59   5]
#  [  5   5 121]]
# Epoch 17/99
# ----------
# train Loss: 0.4146 Acc: 0.8230
# val Loss: 0.5468 Acc: 0.7139
# Confusion Matrix:
# [[ 61  37   5]
#  [ 39  55   4]
#  [  6   4 121]]
# Epoch 18/99
# ----------
# train Loss: 0.4067 Acc: 0.8208
# val Loss: 0.5580 Acc: 0.7048
# Confusion Matrix:
# [[ 55  43   5]
#  [ 33  61   4]
#  [  9   4 118]]
# Epoch 19/99
# ----------
# train Loss: 0.4284 Acc: 0.8020
# val Loss: 0.5447 Acc: 0.7078
# Confusion Matrix:
# [[ 59  38   6]
#  [ 38  55   5]
#  [  6   4 121]]
# Epoch 20/99
# ----------
# train Loss: 0.4062 Acc: 0.8215
# val Loss: 0.5517 Acc: 0.7108
# Confusion Matrix:
# [[ 59  40   4]
#  [ 36  59   3]
#  [  9   4 118]]
# Epoch 21/99
# ----------
# train Loss: 0.3888 Acc: 0.8343
# val Loss: 0.5483 Acc: 0.6898
# Confusion Matrix:
# [[ 51  47   5]
#  [ 36  58   4]
#  [  5   6 120]]
# Epoch 22/99
# ----------
# train Loss: 0.4016 Acc: 0.8163
# val Loss: 0.5461 Acc: 0.7139
# Confusion Matrix:
# [[ 60  38   5]
#  [ 37  57   4]
#  [  6   5 120]]
# Epoch 23/99
# ----------
# train Loss: 0.3727 Acc: 0.8411
# val Loss: 0.5492 Acc: 0.6928
# Confusion Matrix:
# [[ 50  46   7]
#  [ 35  58   5]
#  [  4   5 122]]
# Epoch 24/99
# ----------
# train Loss: 0.3817 Acc: 0.8230
# val Loss: 0.5523 Acc: 0.6898
# Confusion Matrix:
# [[ 54  44   5]
#  [ 38  56   4]
#  [  8   4 119]]
# Epoch 25/99
# ----------
# train Loss: 0.3848 Acc: 0.8185
# val Loss: 0.5527 Acc: 0.7018
# Confusion Matrix:
# [[ 51  45   7]
#  [ 32  61   5]
#  [  4   6 121]]
# Epoch 26/99
# ----------
# train Loss: 0.3798 Acc: 0.8328
# val Loss: 0.5500 Acc: 0.7169
# Confusion Matrix:
# [[ 60  37   6]
#  [ 39  55   4]
#  [  4   4 123]]
# Epoch 27/99
# ----------
# train Loss: 0.3649 Acc: 0.8479
# val Loss: 0.5517 Acc: 0.6928
# Confusion Matrix:
# [[ 51  45   7]
#  [ 37  57   4]
#  [  4   5 122]]
# Epoch 28/99
# ----------
# train Loss: 0.3638 Acc: 0.8426
# val Loss: 0.5474 Acc: 0.7048
# Confusion Matrix:
# [[ 55  42   6]
#  [ 35  59   4]
#  [  6   5 120]]
# Epoch 29/99
# ----------
# train Loss: 0.3606 Acc: 0.8464
# val Loss: 0.5484 Acc: 0.7018
# Confusion Matrix:
# [[ 56  41   6]
#  [ 36  58   4]
#  [  7   5 119]]
# Epoch 30/99
# ----------
# train Loss: 0.3596 Acc: 0.8404
# val Loss: 0.5510 Acc: 0.6988
# Confusion Matrix:
# [[ 53  45   5]
#  [ 33  61   4]
#  [  6   7 118]]
# Epoch 31/99
# ----------
# train Loss: 0.3577 Acc: 0.8517
# val Loss: 0.5506 Acc: 0.6958
# Confusion Matrix:
# [[ 52  44   7]
#  [ 33  60   5]
#  [  6   6 119]]
# Epoch 32/99
# ----------
# train Loss: 0.3547 Acc: 0.8441
# val Loss: 0.5535 Acc: 0.7078
# Confusion Matrix:
# [[ 58  40   5]
#  [ 36  58   4]
#  [  7   5 119]]
# Epoch 33/99
# ----------
# train Loss: 0.3622 Acc: 0.8381
# val Loss: 0.5501 Acc: 0.7229
# Confusion Matrix:
# [[ 59  39   5]
#  [ 34  59   5]
#  [  5   4 122]]
# Epoch 34/99
# ----------
# train Loss: 0.3533 Acc: 0.8479
# val Loss: 0.5467 Acc: 0.6988
# Confusion Matrix:
# [[ 56  40   7]
#  [ 37  56   5]
#  [  5   6 120]]
# Epoch 35/99
# ----------
# train Loss: 0.3416 Acc: 0.8554
# val Loss: 0.5490 Acc: 0.7048
# Confusion Matrix:
# [[ 53  43   7]
#  [ 33  60   5]
#  [  4   6 121]]
# Epoch 36/99
# ----------
# train Loss: 0.3562 Acc: 0.8562
# val Loss: 0.5486 Acc: 0.7108
# Confusion Matrix:
# [[ 55  41   7]
#  [ 34  59   5]
#  [  3   6 122]]
# Epoch 37/99
# ----------
# train Loss: 0.3564 Acc: 0.8509
# val Loss: 0.5491 Acc: 0.7139
# Confusion Matrix:
# [[ 55  41   7]
#  [ 33  60   5]
#  [  4   5 122]]
# Epoch 38/99
# ----------
# train Loss: 0.3480 Acc: 0.8599
# val Loss: 0.5477 Acc: 0.7018
# Confusion Matrix:
# [[ 54  42   7]
#  [ 33  60   5]
#  [  5   7 119]]
# Epoch 39/99
# ----------
# train Loss: 0.3498 Acc: 0.8592
# val Loss: 0.5511 Acc: 0.6988
# Confusion Matrix:
# [[ 52  47   4]
#  [ 32  61   5]
#  [  5   7 119]]
# Epoch 40/99
# ----------
# train Loss: 0.3613 Acc: 0.8479
# val Loss: 0.5478 Acc: 0.7108
# Confusion Matrix:
# [[ 59  39   5]
#  [ 35  59   4]
#  [  6   7 118]]
# Epoch 41/99
# ----------
# train Loss: 0.3569 Acc: 0.8434
# val Loss: 0.5491 Acc: 0.7108
# Confusion Matrix:
# [[ 54  43   6]
#  [ 33  60   5]
#  [  3   6 122]]
# Epoch 42/99
# ----------
# train Loss: 0.3531 Acc: 0.8524
# val Loss: 0.5499 Acc: 0.7018
# Confusion Matrix:
# [[ 52  44   7]
#  [ 34  59   5]
#  [  3   6 122]]
# Epoch 43/99
# ----------
# train Loss: 0.3368 Acc: 0.8592
# val Loss: 0.5495 Acc: 0.7108
# Confusion Matrix:
# [[ 56  40   7]
#  [ 34  59   5]
#  [  4   6 121]]
# Epoch 44/99
# ----------
# train Loss: 0.3538 Acc: 0.8464
# val Loss: 0.5509 Acc: 0.7108
# Confusion Matrix:
# [[ 55  41   7]
#  [ 33  60   5]
#  [  4   6 121]]
# Epoch 45/99
# ----------
# train Loss: 0.3421 Acc: 0.8486
# val Loss: 0.5472 Acc: 0.7139
# Confusion Matrix:
# [[ 57  40   6]
#  [ 34  59   5]
#  [  4   6 121]]
# Epoch 46/99
# ----------
# train Loss: 0.3494 Acc: 0.8464
# val Loss: 0.5484 Acc: 0.7108
# Confusion Matrix:
# [[ 56  40   7]
#  [ 34  59   5]
#  [  4   6 121]]
# Epoch 47/99
# ----------
# train Loss: 0.3573 Acc: 0.8456
# val Loss: 0.5476 Acc: 0.7169
# Confusion Matrix:
# [[ 57  41   5]
#  [ 33  60   5]
#  [  4   6 121]]
# Epoch 48/99
# ----------
# train Loss: 0.3520 Acc: 0.8547
# val Loss: 0.5509 Acc: 0.7048
# Confusion Matrix:
# [[ 56  42   5]
#  [ 34  59   5]
#  [  4   8 119]]
# Epoch 49/99
# ----------
# train Loss: 0.3450 Acc: 0.8577
# val Loss: 0.5508 Acc: 0.7018
# Confusion Matrix:
# [[ 54  43   6]
#  [ 35  58   5]
#  [  4   6 121]]
# Epoch 50/99
# ----------
# train Loss: 0.3538 Acc: 0.8562
# val Loss: 0.5497 Acc: 0.7078
# Confusion Matrix:
# [[ 58  40   5]
#  [ 34  59   5]
#  [  6   7 118]]
# Epoch 51/99
# ----------
# train Loss: 0.3391 Acc: 0.8539
# val Loss: 0.5501 Acc: 0.7018
# Confusion Matrix:
# [[ 54  44   5]
#  [ 35  58   5]
#  [  4   6 121]]
# Epoch 52/99
# ----------
# train Loss: 0.3307 Acc: 0.8614
# val Loss: 0.5466 Acc: 0.7078
# Confusion Matrix:
# [[ 57  41   5]
#  [ 36  58   4]
#  [  5   6 120]]
# Epoch 53/99
# ----------
# train Loss: 0.3374 Acc: 0.8584
# val Loss: 0.5504 Acc: 0.7018
# Confusion Matrix:
# [[ 56  40   7]
#  [ 35  58   5]
#  [  5   7 119]]
# Epoch 54/99
# ----------
# train Loss: 0.3344 Acc: 0.8569
# val Loss: 0.5475 Acc: 0.7078
# Confusion Matrix:
# [[ 57  40   6]
#  [ 35  58   5]
#  [  6   5 120]]
# Epoch 55/99
# ----------
# train Loss: 0.3511 Acc: 0.8441
# val Loss: 0.5497 Acc: 0.7078
# Confusion Matrix:
# [[ 55  42   6]
#  [ 34  59   5]
#  [  4   6 121]]
# Epoch 56/99
# ----------
# train Loss: 0.3561 Acc: 0.8502
# val Loss: 0.5483 Acc: 0.7048
# Confusion Matrix:
# [[ 58  40   5]
#  [ 35  58   5]
#  [  6   7 118]]
# Epoch 57/99
# ----------
# train Loss: 0.3356 Acc: 0.8486
# val Loss: 0.5489 Acc: 0.7078
# Confusion Matrix:
# [[ 56  43   4]
#  [ 33  60   5]
#  [  6   6 119]]
# Epoch 58/99
# ----------
# train Loss: 0.3528 Acc: 0.8456
# val Loss: 0.5482 Acc: 0.7229
# Confusion Matrix:
# [[ 58  39   6]
#  [ 32  61   5]
#  [  5   5 121]]
# Epoch 59/99
# ----------
# train Loss: 0.3524 Acc: 0.8539
# val Loss: 0.5486 Acc: 0.7048
# Confusion Matrix:
# [[ 57  40   6]
#  [ 35  58   5]
#  [  7   5 119]]
# Epoch 60/99
# ----------
# train Loss: 0.3411 Acc: 0.8637
# val Loss: 0.5466 Acc: 0.7169
# Confusion Matrix:
# [[ 57  40   6]
#  [ 34  59   5]
#  [  3   6 122]]
# Epoch 61/99
# ----------
# train Loss: 0.3511 Acc: 0.8502
# val Loss: 0.5482 Acc: 0.7108
# Confusion Matrix:
# [[ 55  42   6]
#  [ 34  59   5]
#  [  3   6 122]]
# Epoch 62/99
# ----------
# train Loss: 0.3311 Acc: 0.8645
# val Loss: 0.5493 Acc: 0.7139
# Confusion Matrix:
# [[ 57  40   6]
#  [ 34  59   5]
#  [  5   5 121]]
# Epoch 63/99
# ----------
# train Loss: 0.3330 Acc: 0.8630
# val Loss: 0.5501 Acc: 0.7108
# Confusion Matrix:
# [[ 58  41   4]
#  [ 34  59   5]
#  [  7   5 119]]
# Epoch 64/99
# ----------
# train Loss: 0.3515 Acc: 0.8381
# val Loss: 0.5483 Acc: 0.7108
# Confusion Matrix:
# [[ 58  42   3]
#  [ 34  59   5]
#  [  6   6 119]]
# Epoch 65/99
# ----------
# train Loss: 0.3484 Acc: 0.8509
# val Loss: 0.5486 Acc: 0.7078
# Confusion Matrix:
# [[ 55  41   7]
#  [ 34  59   5]
#  [  5   5 121]]
# Epoch 66/99
# ----------
# train Loss: 0.3397 Acc: 0.8569
# val Loss: 0.5486 Acc: 0.7078
# Confusion Matrix:
# [[ 53  44   6]
#  [ 32  61   5]
#  [  3   7 121]]
# Epoch 67/99
# ----------
# train Loss: 0.3312 Acc: 0.8682
# val Loss: 0.5499 Acc: 0.7139
# Confusion Matrix:
# [[ 58  40   5]
#  [ 33  60   5]
#  [  7   5 119]]
# Epoch 68/99
# ----------
# train Loss: 0.3362 Acc: 0.8652
# val Loss: 0.5492 Acc: 0.7169
# Confusion Matrix:
# [[ 57  42   4]
#  [ 31  62   5]
#  [  6   6 119]]
# Epoch 69/99
# ----------
# train Loss: 0.3481 Acc: 0.8622
# val Loss: 0.5518 Acc: 0.7139
# Confusion Matrix:
# [[ 55  41   7]
#  [ 33  60   5]
#  [  4   5 122]]
# Epoch 70/99
# ----------
# train Loss: 0.3423 Acc: 0.8547
# val Loss: 0.5501 Acc: 0.6988
# Confusion Matrix:
# [[ 54  43   6]
#  [ 37  56   5]
#  [  3   6 122]]
# Epoch 71/99
# ----------
# train Loss: 0.3458 Acc: 0.8599
# val Loss: 0.5483 Acc: 0.7139
# Confusion Matrix:
# [[ 57  39   7]
#  [ 34  59   5]
#  [  4   6 121]]
# Epoch 72/99
# ----------
# train Loss: 0.3434 Acc: 0.8554
# val Loss: 0.5472 Acc: 0.7108
# Confusion Matrix:
# [[ 57  40   6]
#  [ 35  58   5]
#  [  5   5 121]]
# Epoch 73/99
# ----------
# train Loss: 0.3554 Acc: 0.8554
# val Loss: 0.5500 Acc: 0.7078
# Confusion Matrix:
# [[ 57  40   6]
#  [ 34  59   5]
#  [  6   6 119]]
# Epoch 74/99
# ----------
# train Loss: 0.3464 Acc: 0.8637
# val Loss: 0.5474 Acc: 0.7169
# Confusion Matrix:
# [[ 58  40   5]
#  [ 33  61   4]
#  [  5   7 119]]
# Epoch 75/99
# ----------
# train Loss: 0.3491 Acc: 0.8562
# val Loss: 0.5498 Acc: 0.7199
# Confusion Matrix:
# [[ 58  41   4]
#  [ 32  61   5]
#  [  5   6 120]]
# Epoch 76/99
# ----------
# train Loss: 0.3613 Acc: 0.8456
# val Loss: 0.5490 Acc: 0.7199
# Confusion Matrix:
# [[ 56  42   5]
#  [ 32  61   5]
#  [  3   6 122]]
# Epoch 77/99
# ----------
# train Loss: 0.3461 Acc: 0.8509
# val Loss: 0.5489 Acc: 0.7048
# Confusion Matrix:
# [[ 56  42   5]
#  [ 35  58   5]
#  [  5   6 120]]
# Epoch 78/99
# ----------
# train Loss: 0.3357 Acc: 0.8630
# val Loss: 0.5479 Acc: 0.7108
# Confusion Matrix:
# [[ 57  41   5]
#  [ 34  59   5]
#  [  5   6 120]]
# Epoch 79/99
# ----------
# train Loss: 0.3532 Acc: 0.8509
# val Loss: 0.5486 Acc: 0.7048
# Confusion Matrix:
# [[ 57  41   5]
#  [ 35  59   4]
#  [  6   7 118]]
# Epoch 80/99
# ----------
# train Loss: 0.3498 Acc: 0.8577
# val Loss: 0.5499 Acc: 0.7048
# Confusion Matrix:
# [[ 54  44   5]
#  [ 31  62   5]
#  [  6   7 118]]
# Epoch 81/99
# ----------
# train Loss: 0.3446 Acc: 0.8584
# val Loss: 0.5495 Acc: 0.7139
# Confusion Matrix:
# [[ 57  41   5]
#  [ 32  61   5]
#  [  6   6 119]]
# Epoch 82/99
# ----------
# train Loss: 0.3441 Acc: 0.8562
# val Loss: 0.5498 Acc: 0.7078
# Confusion Matrix:
# [[ 57  40   6]
#  [ 34  59   5]
#  [  6   6 119]]
# Epoch 83/99
# ----------
# train Loss: 0.3433 Acc: 0.8494
# val Loss: 0.5490 Acc: 0.7108
# Confusion Matrix:
# [[ 55  41   7]
#  [ 34  59   5]
#  [  4   5 122]]
# Epoch 84/99
# ----------
# train Loss: 0.3474 Acc: 0.8592
# val Loss: 0.5471 Acc: 0.7078
# Confusion Matrix:
# [[ 57  40   6]
#  [ 35  59   4]
#  [  7   5 119]]
# Epoch 85/99
# ----------
# train Loss: 0.3387 Acc: 0.8532
# val Loss: 0.5488 Acc: 0.7108
# Confusion Matrix:
# [[ 58  40   5]
#  [ 34  60   4]
#  [  6   7 118]]
# Epoch 86/99
# ----------
# train Loss: 0.3406 Acc: 0.8517
# val Loss: 0.5517 Acc: 0.7048
# Confusion Matrix:
# [[ 57  41   5]
#  [ 34  59   5]
#  [  6   7 118]]
# Epoch 87/99
# ----------
# train Loss: 0.3406 Acc: 0.8539
# val Loss: 0.5493 Acc: 0.7108
# Confusion Matrix:
# [[ 58  40   5]
#  [ 34  59   5]
#  [  6   6 119]]
# Epoch 88/99
# ----------
# train Loss: 0.3510 Acc: 0.8449
# val Loss: 0.5502 Acc: 0.7108
# Confusion Matrix:
# [[ 55  42   6]
#  [ 34  59   5]
#  [  3   6 122]]
# Epoch 89/99
# ----------
# train Loss: 0.3562 Acc: 0.8532
# val Loss: 0.5507 Acc: 0.7139
# Confusion Matrix:
# [[ 56  41   6]
#  [ 32  61   5]
#  [  5   6 120]]
# Epoch 90/99
# ----------
# train Loss: 0.3464 Acc: 0.8524
# val Loss: 0.5480 Acc: 0.7108
# Confusion Matrix:
# [[ 56  40   7]
#  [ 34  59   5]
#  [  5   5 121]]
# Epoch 91/99
# ----------
# train Loss: 0.3442 Acc: 0.8577
# val Loss: 0.5484 Acc: 0.7108
# Confusion Matrix:
# [[ 57  40   6]
#  [ 34  59   5]
#  [  6   5 120]]
# Epoch 92/99
# ----------
# train Loss: 0.3402 Acc: 0.8554
# val Loss: 0.5503 Acc: 0.7108
# Confusion Matrix:
# [[ 55  42   6]
#  [ 34  59   5]
#  [  3   6 122]]
# Epoch 93/99
# ----------
# train Loss: 0.3322 Acc: 0.8652
# val Loss: 0.5493 Acc: 0.7169
# Confusion Matrix:
# [[ 57  40   6]
#  [ 33  60   5]
#  [  5   5 121]]
# Epoch 94/99
# ----------
# train Loss: 0.3385 Acc: 0.8592
# val Loss: 0.5494 Acc: 0.7078
# Confusion Matrix:
# [[ 56  40   7]
#  [ 34  59   5]
#  [  4   7 120]]
# Epoch 95/99
# ----------
# train Loss: 0.3516 Acc: 0.8532
# val Loss: 0.5493 Acc: 0.7048
# Confusion Matrix:
# [[ 56  40   7]
#  [ 35  58   5]
#  [  6   5 120]]
# Epoch 96/99
# ----------
# train Loss: 0.3412 Acc: 0.8517
# val Loss: 0.5496 Acc: 0.7108
# Confusion Matrix:
# [[ 56  42   5]
#  [ 34  59   5]
#  [  4   6 121]]
# Epoch 97/99
# ----------
# train Loss: 0.3395 Acc: 0.8675
# val Loss: 0.5493 Acc: 0.7048
# Confusion Matrix:
# [[ 57  41   5]
#  [ 35  58   5]
#  [  6   6 119]]
# Epoch 98/99
# ----------
# train Loss: 0.3512 Acc: 0.8404
# val Loss: 0.5483 Acc: 0.7108
# Confusion Matrix:
# [[ 56  40   7]
#  [ 35  58   5]
#  [  3   6 122]]
# Epoch 99/99
# ----------
# train Loss: 0.3577 Acc: 0.8449
# val Loss: 0.5504 Acc: 0.7048
# Confusion Matrix:
# [[ 56  42   5]
#  [ 34  59   5]
#  [  7   5 119]]
# Training complete in 0m 42s
# Best val Acc: 0.722892

# %%
plot_loss_with_MyModel(finetuned_MyModel, plot_title = "CNN Model")

# %%
plot_cm_with_MyModel(MyModel_here = finetuned_MyModel, plot_title = "CNN Model")

# %%
torch.save(finetuned_MyModel.model, './model/EarthquakeCNN_finetuned.pth')
