# %%
import copy
import torch
import time
import os

import torch.optim as optim
import torch.nn as nn
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from torch.utils.data import DataLoader
from torch.utils.data import Dataset
from torch.optim import lr_scheduler
from sklearn.metrics import confusion_matrix
from sklearn.model_selection import train_test_split
from def_model import EarthquakeCNN

import functions

# %%
class EarthquakeDataset(Dataset):
    def __init__(self, features, labels):
        self.features = features
        self.labels = labels

    def __len__(self):
        return len(self.features)

    def __getitem__(self, idx):
        return self.features[idx], self.labels[idx]

# %%
datadir = './data_QSIS_pth'

train_data_path = os.path.join(datadir, "all_merged.pth")
train_data = torch.load(train_data_path)
Xall = train_data['Xall']
Yall = train_data['Yall']

# %%
Xall, Yall = functions.remove_small_amplitude(Xall, Yall) 
Xall, Yall = functions.remove_large_amplitude(Xall, Yall)
log10_amplitude = np.log10(np.max(np.abs(Xall), axis = (1, 2, 3)))
Xall = functions.normalize(Xall)
Xall = functions.quantize(Xall)
Xall = Xall.astype(np.float32)
Xall = functions.normalize(Xall)

# %%
Xall = torch.from_numpy(Xall).float()
Yall = torch.from_numpy(Yall).float()

Xall = Xall.permute(0, 3, 1, 2)

# %%
# split the data into training and validation datasets
X_train, X_val, Y_train, Y_val = train_test_split(Xall, Yall, test_size = 0.2, random_state = 42)

# create datasets
train_dataset = EarthquakeDataset(X_train, Y_train)
val_dataset = EarthquakeDataset(X_val, Y_val)

# create dataloaders
train_dataloader = DataLoader(train_dataset, batch_size = 32, shuffle = True)
val_dataloader = DataLoader(val_dataset, batch_size = 32, shuffle = True)

# put dataloaders into a dictionary
dataloaders = {
    'train': train_dataloader,
    'val': val_dataloader
}

# similarly, create a dictionary for dataset sizes
dataset_sizes = {
    'train': len(train_dataset),
    'val': len(val_dataset)
}

# %%
print(X_train.shape)
print(Y_train.shape)
# Out:
# torch.Size([1328, 1, 80, 3])
# torch.Size([1328, 3])

# %%
class MyModel:
    def __init__(self, model, epoch_arr, train_loss_arr, val_loss_arr, train_acc_arr, val_acc_arr, lr_arr, cm, best_acc):
        self.model = model
        self.epoch_arr = epoch_arr
        self.train_loss_arr = train_loss_arr
        self.val_loss_arr = val_loss_arr
        self.train_acc_arr = train_acc_arr
        self.val_acc_arr = val_acc_arr
        self.lr_arr = lr_arr
        self.cm = cm
        self.best_acc = best_acc

# %%
def plot_loss_with_MyModel(MyModel_here, plot_title = "Default"):
    epoch_arr_here = MyModel_here.epoch_arr
    train_loss_arr_here = MyModel_here.train_loss_arr
    val_loss_arr_here = MyModel_here.val_loss_arr
    train_acc_arr_here = MyModel_here.train_acc_arr
    val_acc_arr_here = MyModel_here.val_acc_arr
    lr_arr_here = MyModel_here.lr_arr

    fig_loss_func, axes_loss_func = plt.subplots(nrows = 1, ncols = 3, figsize = (24, 6))
    fig_loss_func.suptitle(plot_title)

    axes_loss_func[0].plot(epoch_arr_here, train_loss_arr_here, label = 'Training Loss')
    axes_loss_func[0].plot(epoch_arr_here, val_loss_arr_here, label = 'Validation Loss')
    axes_loss_func[0].set_title('Loss')
    axes_loss_func[0].set_xlabel('Epoch')
    axes_loss_func[0].set_ylabel('Loss')
    axes_loss_func[0].legend()
    axes_loss_func[1].plot(epoch_arr_here, train_acc_arr_here, label = 'Training Accuracy')
    axes_loss_func[1].plot(epoch_arr_here, val_acc_arr_here, label = 'Validation Accuracy')
    axes_loss_func[1].set_title('Accuracy')
    axes_loss_func[1].set_xlabel('Epoch')
    axes_loss_func[1].set_ylabel('Accurracy')
    axes_loss_func[1].legend()
    axes_loss_func[2].plot(epoch_arr_here, lr_arr_here, label = 'Learning Rate')
    axes_loss_func[2].set_title('Learning Rate')
    axes_loss_func[2].set_xlabel('Epoch')
    axes_loss_func[2].set_ylabel('Accuracy')
    axes_loss_func[2].legend()
    fig_loss_func.tight_layout()
    plt.savefig('./Result_Finetuing/Accurracy.pdf')

# %%
def plot_cm_with_MyModel(MyModel_here, plot_title = "Default"):

    cm_here = MyModel_here.cm
    cm_here = cm_here.astype('float') / cm_here.sum(axis = 1)[:, np.newaxis]

    labels = ['P-wave', 'S-wave', 'Noise']
    cm_here_df = pd.DataFrame(cm_here, index = labels, columns = labels)
    cm_here = cm_here_df

    fig_cm_func, axes_cm_func = plt.subplots(nrows = 1, ncols = 1, figsize = (8, 6))
    acc_here = MyModel_here.best_acc.detach().cpu().numpy() * 100
    acc_here = round(acc_here, 2)
    fig_cm_func.suptitle(plot_title + ' Confusion Matrix, Accuracy = ' + str(acc_here) + '%')

    sns.heatmap(cm_here, annot = True, cmap = 'Blues', ax = axes_cm_func)
    axes_cm_func.set_title('Train Confusion Matrix')
    axes_cm_func.set_xlabel('Predicted Labels')
    axes_cm_func.set_ylabel('Actual Labels')
    fig_cm_func.tight_layout()

    plt.savefig('./Result_Finetuing/Confusion_Matrix.pdf')

# %%
def train_model(model, criterion, optimizer, scheduler, num_epochs = 25):
    since = time.time()

    best_model_wts = copy.deepcopy(model.state_dict())
    best_acc = 0.0

    epoch_arr = np.array([])
    lr_arr = np.array([])
    train_loss_arr = np.array([])
    train_acc_arr = np.array([])

    val_loss_arr = np.array([])
    val_acc_arr = np.array([])

    for epoch in range(num_epochs):
        print(f'Epoch {epoch}/{num_epochs - 1}')
        print('-' * 10)

        # Each epoch has a training and validation phase
        for phase in ['train', 'val']:
            if phase == 'train':
                model.train()  # Set model to training mode
            else:
                model.eval()   # Set model to evaluate mode

            running_loss = 0.0
            running_corrects = 0

            # These lists will hold all labels and predictions for this epoch
            # all_labels = []
            # all_preds = []

            all_labels = np.array([])
            all_preds = np.array([])

            # Iterate over data.
            for inputs, labels in dataloaders[phase]:
                inputs = inputs
                labels = labels

                # zero the parameter gradients
                optimizer.zero_grad()

                # forward
                # track history if only in train
                with torch.set_grad_enabled(phase == 'train'):
                    outputs = model(inputs)
                    _, preds = torch.max(outputs, 1)
                    _, labels = torch.max(labels.data, 1)
                    loss = criterion(outputs, labels)

                    # backward + optimize only if in training phase
                    if phase == 'train':
                        loss.backward()
                        optimizer.step()

                # statistics
                running_loss += loss.item() * inputs.size(0)
                running_corrects += torch.sum(preds == labels.data)

                # Add current labels and predictions to the lists
                # all_labels.extend(labels.tolist())
                # all_preds.extend(preds.tolist())

                all_labels = np.append(all_labels, labels.tolist())
                all_preds = np.append(all_preds, preds.tolist())

            if phase == 'train':
                scheduler.step()

            epoch_loss = running_loss / dataset_sizes[phase]
            epoch_acc = running_corrects / dataset_sizes[phase]

            print(f'{phase} Loss: {epoch_loss:.4f} Acc: {epoch_acc:.4f}')

            # After each epoch, compute and print the confusion matrix
            if phase == 'val':
                print("Confusion Matrix:")
                cm_here = confusion_matrix(all_labels, all_preds)
                print(cm_here)

            # save the loss and accurracy
            if phase == 'train':
                train_loss_arr = np.append(train_loss_arr, epoch_loss)
                train_acc_arr = np.append(train_acc_arr, epoch_acc.detach().cpu())
                lr_arr = np.append(lr_arr, optimizer.param_groups[0]['lr'])
                epoch_arr = np.append(epoch_arr, epoch)
            elif phase == 'val':
                val_loss_arr = np.append(val_loss_arr, epoch_loss)
                val_acc_arr = np.append(val_acc_arr, epoch_acc.detach().cpu())

            # deep copy the model
            if phase == 'val' and epoch_acc > best_acc:
                best_acc = epoch_acc
                best_model_wts = copy.deepcopy(model.state_dict())

    time_elapsed = time.time() - since
    print(f'Training complete in {time_elapsed // 60:.0f}m {time_elapsed % 60:.0f}s')
    print(f'Best val Acc: {best_acc:4f}')

    # load best model weights
    model.load_state_dict(best_model_wts)

    model_class = MyModel(model = model, 
                          epoch_arr = epoch_arr, 
                          train_loss_arr = train_loss_arr, 
                          val_loss_arr = val_loss_arr, 
                          train_acc_arr = train_acc_arr, 
                          val_acc_arr = val_acc_arr, 
                          lr_arr = lr_arr, 
                          cm = cm_here, 
                          best_acc = best_acc)

    return model_class

# %%
model = torch.load('./model/EarthquakeCNN.pth')
# model = EarthquakeCNN()

# 凍結模型的卷積層
for param in model.parameters():
    # param.requires_grad = False
    param.requires_grad = True

# 全連接層的權重將被更新
for param in model.fc1.parameters():
    param.requires_grad = True
for param in model.fc2.parameters():
    param.requires_grad = True
for param in model.fc3.parameters():
    param.requires_grad = True

# %%
criterion = nn.CrossEntropyLoss()

# 使用Adam優化器，並且設定學習率為0.001
# optimizer = optim.Adam(model.parameters(), lr = 0.001)
optimizer = optim.AdamW(model.parameters(), lr = 0.001)
# optimizer = optim.RAdam(model.parameters(), lr = 0.001)

# 每7個epoch，學習率減半
exp_lr_scheduler = lr_scheduler.StepLR(optimizer, step_size = 7, gamma = 0.5)

# %%
finetuned_MyModel = train_model(model, criterion, optimizer, exp_lr_scheduler, num_epochs = 100)
# Out:
# Epoch 0/99
# ----------
# train Loss: 1.5902 Acc: 0.4270
# val Loss: 0.8223 Acc: 0.5422
# Confusion Matrix:
# [[41 42 20]
#  [32 40 26]
#  [ 5 27 99]]
# Epoch 1/99
# ----------
# train Loss: 0.8108 Acc: 0.5836
# val Loss: 0.7092 Acc: 0.6355
# Confusion Matrix:
# [[ 28  66   9]
#  [ 16  65  17]
#  [  1  12 118]]
# Epoch 2/99
# ----------
# train Loss: 0.7130 Acc: 0.6498
# val Loss: 0.6557 Acc: 0.6717
# Confusion Matrix:
# [[ 43  52   8]
#  [ 23  70   5]
#  [  2  19 110]]
# Epoch 3/99
# ----------
# train Loss: 0.6536 Acc: 0.6642
# val Loss: 0.6033 Acc: 0.7199
# Confusion Matrix:
# [[ 67  28   8]
#  [ 37  50  11]
#  [  1   8 122]]
# Epoch 4/99
# ----------
# train Loss: 0.6257 Acc: 0.6845
# val Loss: 0.5704 Acc: 0.7440
# Confusion Matrix:
# [[ 68  28   7]
#  [ 33  54  11]
#  [  3   3 125]]
# Epoch 5/99
# ----------
# train Loss: 0.6120 Acc: 0.6935
# val Loss: 0.5894 Acc: 0.7048
# Confusion Matrix:
# [[ 43  51   9]
#  [ 21  67  10]
#  [  1   6 124]]
# Epoch 6/99
# ----------
# train Loss: 0.5690 Acc: 0.7093
# val Loss: 0.5540 Acc: 0.7229
# Confusion Matrix:
# [[ 56  39   8]
#  [ 28  60  10]
#  [  1   6 124]]
# Epoch 7/99
# ----------
# train Loss: 0.5259 Acc: 0.7477
# val Loss: 0.5428 Acc: 0.7380
# Confusion Matrix:
# [[ 66  29   8]
#  [ 33  55  10]
#  [  1   6 124]]
# Epoch 8/99
# ----------
# train Loss: 0.5281 Acc: 0.7568
# val Loss: 0.5393 Acc: 0.7410
# Confusion Matrix:
# [[ 62  34   7]
#  [ 27  63   8]
#  [  2   8 121]]
# Epoch 9/99
# ----------
# train Loss: 0.4994 Acc: 0.7613
# val Loss: 0.5478 Acc: 0.7139
# Confusion Matrix:
# [[ 42  55   6]
#  [ 17  75   6]
#  [  1  10 120]]
# Epoch 10/99
# ----------
# train Loss: 0.4979 Acc: 0.7553
# val Loss: 0.5275 Acc: 0.7380
# Confusion Matrix:
# [[ 63  33   7]
#  [ 29  60   9]
#  [  2   7 122]]
# Epoch 11/99
# ----------
# train Loss: 0.4914 Acc: 0.7681
# val Loss: 0.5572 Acc: 0.7380
# Confusion Matrix:
# [[ 52  42   9]
#  [ 17  71  10]
#  [  2   7 122]]
# Epoch 12/99
# ----------
# train Loss: 0.4803 Acc: 0.7688
# val Loss: 0.5255 Acc: 0.7289
# Confusion Matrix:
# [[ 51  47   5]
#  [ 21  70   7]
#  [  2   8 121]]
# Epoch 13/99
# ----------
# train Loss: 0.4524 Acc: 0.7786
# val Loss: 0.5325 Acc: 0.7108
# Confusion Matrix:
# [[ 43  54   6]
#  [ 18  71   9]
#  [  2   7 122]]
# Epoch 14/99
# ----------
# train Loss: 0.4611 Acc: 0.7711
# val Loss: 0.5338 Acc: 0.7259
# Confusion Matrix:
# [[ 60  39   4]
#  [ 30  62   6]
#  [  3   9 119]]
# Epoch 15/99
# ----------
# train Loss: 0.4346 Acc: 0.7831
# val Loss: 0.5286 Acc: 0.7349
# Confusion Matrix:
# [[ 66  32   5]
#  [ 33  58   7]
#  [  3   8 120]]
# Epoch 16/99
# ----------
# train Loss: 0.4345 Acc: 0.7929
# val Loss: 0.5267 Acc: 0.7229
# Confusion Matrix:
# [[ 51  48   4]
#  [ 23  68   7]
#  [  2   8 121]]
# Epoch 17/99
# ----------
# train Loss: 0.4174 Acc: 0.8020
# val Loss: 0.5313 Acc: 0.7199
# Confusion Matrix:
# [[ 61  40   2]
#  [ 32  60   6]
#  [  3  10 118]]
# Epoch 18/99
# ----------
# train Loss: 0.4347 Acc: 0.7884
# val Loss: 0.5293 Acc: 0.7259
# Confusion Matrix:
# [[ 60  41   2]
#  [ 31  61   6]
#  [  2   9 120]]
# Epoch 19/99
# ----------
# train Loss: 0.4134 Acc: 0.8035
# val Loss: 0.5212 Acc: 0.7229
# Confusion Matrix:
# [[ 63  37   3]
#  [ 35  57   6]
#  [  3   8 120]]
# Epoch 20/99
# ----------
# train Loss: 0.4151 Acc: 0.8005
# val Loss: 0.5235 Acc: 0.7139
# Confusion Matrix:
# [[ 49  50   4]
#  [ 24  66   8]
#  [  2   7 122]]
# Epoch 21/99
# ----------
# train Loss: 0.4332 Acc: 0.7914
# val Loss: 0.5255 Acc: 0.7139
# Confusion Matrix:
# [[ 54  47   2]
#  [ 27  65   6]
#  [  3  10 118]]
# Epoch 22/99
# ----------
# train Loss: 0.4002 Acc: 0.8245
# val Loss: 0.5213 Acc: 0.7108
# Confusion Matrix:
# [[ 52  47   4]
#  [ 26  64   8]
#  [  2   9 120]]
# Epoch 23/99
# ----------
# train Loss: 0.3890 Acc: 0.8185
# val Loss: 0.5206 Acc: 0.7139
# Confusion Matrix:
# [[ 51  48   4]
#  [ 25  66   7]
#  [  2   9 120]]
# Epoch 24/99
# ----------
# train Loss: 0.3952 Acc: 0.8163
# val Loss: 0.5347 Acc: 0.7018
# Confusion Matrix:
# [[ 46  54   3]
#  [ 22  68   8]
#  [  2  10 119]]
# Epoch 25/99
# ----------
# train Loss: 0.3850 Acc: 0.8208
# val Loss: 0.5207 Acc: 0.7319
# Confusion Matrix:
# [[ 60  42   1]
#  [ 27  64   7]
#  [  2  10 119]]
# Epoch 26/99
# ----------
# train Loss: 0.3881 Acc: 0.8261
# val Loss: 0.5345 Acc: 0.7108
# Confusion Matrix:
# [[ 51  47   5]
#  [ 25  66   7]
#  [  2  10 119]]
# Epoch 27/99
# ----------
# train Loss: 0.3826 Acc: 0.8200
# val Loss: 0.5259 Acc: 0.7259
# Confusion Matrix:
# [[ 52  49   2]
#  [ 22  70   6]
#  [  2  10 119]]
# Epoch 28/99
# ----------
# train Loss: 0.3996 Acc: 0.8095
# val Loss: 0.5228 Acc: 0.7319
# Confusion Matrix:
# [[ 59  42   2]
#  [ 26  65   7]
#  [  2  10 119]]
# Epoch 29/99
# ----------
# train Loss: 0.3816 Acc: 0.8291
# val Loss: 0.5224 Acc: 0.7139
# Confusion Matrix:
# [[ 49  50   4]
#  [ 22  68   8]
#  [  2   9 120]]
# Epoch 30/99
# ----------
# train Loss: 0.3795 Acc: 0.8343
# val Loss: 0.5258 Acc: 0.7199
# Confusion Matrix:
# [[ 54  46   3]
#  [ 24  66   8]
#  [  2  10 119]]
# Epoch 31/99
# ----------
# train Loss: 0.3849 Acc: 0.8253
# val Loss: 0.5236 Acc: 0.7108
# Confusion Matrix:
# [[ 50  50   3]
#  [ 23  67   8]
#  [  2  10 119]]
# Epoch 32/99
# ----------
# train Loss: 0.3755 Acc: 0.8140
# val Loss: 0.5219 Acc: 0.7259
# Confusion Matrix:
# [[ 53  47   3]
#  [ 24  67   7]
#  [  2   8 121]]
# Epoch 33/99
# ----------
# train Loss: 0.3785 Acc: 0.8230
# val Loss: 0.5244 Acc: 0.7289
# Confusion Matrix:
# [[ 59  43   1]
#  [ 27  65   6]
#  [  3  10 118]]
# Epoch 34/99
# ----------
# train Loss: 0.3625 Acc: 0.8396
# val Loss: 0.5273 Acc: 0.7169
# Confusion Matrix:
# [[ 53  48   2]
#  [ 25  66   7]
#  [  2  10 119]]
# Epoch 35/99
# ----------
# train Loss: 0.3902 Acc: 0.8223
# val Loss: 0.5219 Acc: 0.7259
# Confusion Matrix:
# [[ 55  45   3]
#  [ 26  65   7]
#  [  2   8 121]]
# Epoch 36/99
# ----------
# train Loss: 0.3711 Acc: 0.8313
# val Loss: 0.5270 Acc: 0.7229
# Confusion Matrix:
# [[ 55  45   3]
#  [ 26  65   7]
#  [  2   9 120]]
# Epoch 37/99
# ----------
# train Loss: 0.3744 Acc: 0.8441
# val Loss: 0.5286 Acc: 0.7259
# Confusion Matrix:
# [[ 54  46   3]
#  [ 24  67   7]
#  [  2   9 120]]
# Epoch 38/99
# ----------
# train Loss: 0.3525 Acc: 0.8494
# val Loss: 0.5213 Acc: 0.7259
# Confusion Matrix:
# [[ 55  44   4]
#  [ 26  65   7]
#  [  2   8 121]]
# Epoch 39/99
# ----------
# train Loss: 0.3569 Acc: 0.8456
# val Loss: 0.5202 Acc: 0.7380
# Confusion Matrix:
# [[ 60  40   3]
#  [ 27  64   7]
#  [  2   8 121]]
# Epoch 40/99
# ----------
# train Loss: 0.3642 Acc: 0.8358
# val Loss: 0.5385 Acc: 0.7229
# Confusion Matrix:
# [[ 59  42   2]
#  [ 29  63   6]
#  [  3  10 118]]
# Epoch 41/99
# ----------
# train Loss: 0.3555 Acc: 0.8381
# val Loss: 0.5285 Acc: 0.7199
# Confusion Matrix:
# [[ 58  44   1]
#  [ 29  63   6]
#  [  3  10 118]]
# Epoch 42/99
# ----------
# train Loss: 0.3513 Acc: 0.8434
# val Loss: 0.5178 Acc: 0.7259
# Confusion Matrix:
# [[ 54  46   3]
#  [ 25  66   7]
#  [  2   8 121]]
# Epoch 43/99
# ----------
# train Loss: 0.3543 Acc: 0.8471
# val Loss: 0.5290 Acc: 0.7229
# Confusion Matrix:
# [[ 57  45   1]
#  [ 27  65   6]
#  [  3  10 118]]
# Epoch 44/99
# ----------
# train Loss: 0.3693 Acc: 0.8321
# val Loss: 0.5246 Acc: 0.7259
# Confusion Matrix:
# [[ 54  45   4]
#  [ 25  66   7]
#  [  2   8 121]]
# Epoch 45/99
# ----------
# train Loss: 0.3517 Acc: 0.8328
# val Loss: 0.5220 Acc: 0.7229
# Confusion Matrix:
# [[ 55  45   3]
#  [ 26  65   7]
#  [  2   9 120]]
# Epoch 46/99
# ----------
# train Loss: 0.3683 Acc: 0.8313
# val Loss: 0.5192 Acc: 0.7289
# Confusion Matrix:
# [[ 54  46   3]
#  [ 24  67   7]
#  [  2   8 121]]
# Epoch 47/99
# ----------
# train Loss: 0.3670 Acc: 0.8464
# val Loss: 0.5261 Acc: 0.7199
# Confusion Matrix:
# [[ 54  45   4]
#  [ 25  66   7]
#  [  2  10 119]]
# Epoch 48/99
# ----------
# train Loss: 0.3558 Acc: 0.8343
# val Loss: 0.5295 Acc: 0.7169
# Confusion Matrix:
# [[ 54  45   4]
#  [ 26  65   7]
#  [  2  10 119]]
# Epoch 49/99
# ----------
# train Loss: 0.3635 Acc: 0.8396
# val Loss: 0.5244 Acc: 0.7199
# Confusion Matrix:
# [[ 55  44   4]
#  [ 27  64   7]
#  [  2   9 120]]
# Epoch 50/99
# ----------
# train Loss: 0.3556 Acc: 0.8373
# val Loss: 0.5227 Acc: 0.7259
# Confusion Matrix:
# [[ 57  43   3]
#  [ 27  64   7]
#  [  2   9 120]]
# Epoch 51/99
# ----------
# train Loss: 0.3529 Acc: 0.8404
# val Loss: 0.5289 Acc: 0.7229
# Confusion Matrix:
# [[ 55  45   3]
#  [ 24  67   7]
#  [  3  10 118]]
# Epoch 52/99
# ----------
# train Loss: 0.3474 Acc: 0.8411
# val Loss: 0.5278 Acc: 0.7199
# Confusion Matrix:
# [[ 55  44   4]
#  [ 27  64   7]
#  [  2   9 120]]
# Epoch 53/99
# ----------
# train Loss: 0.3627 Acc: 0.8389
# val Loss: 0.5251 Acc: 0.7169
# Confusion Matrix:
# [[ 54  45   4]
#  [ 27  64   7]
#  [  2   9 120]]
# Epoch 54/99
# ----------
# train Loss: 0.3597 Acc: 0.8389
# val Loss: 0.5263 Acc: 0.7169
# Confusion Matrix:
# [[ 54  45   4]
#  [ 26  65   7]
#  [  2  10 119]]
# Epoch 55/99
# ----------
# train Loss: 0.3625 Acc: 0.8366
# val Loss: 0.5287 Acc: 0.7169
# Confusion Matrix:
# [[ 54  45   4]
#  [ 26  65   7]
#  [  2  10 119]]
# Epoch 56/99
# ----------
# train Loss: 0.3623 Acc: 0.8389
# val Loss: 0.5302 Acc: 0.7139
# Confusion Matrix:
# [[ 54  45   4]
#  [ 26  65   7]
#  [  3  10 118]]
# Epoch 57/99
# ----------
# train Loss: 0.3649 Acc: 0.8419
# val Loss: 0.5267 Acc: 0.7259
# Confusion Matrix:
# [[ 53  47   3]
#  [ 23  68   7]
#  [  2   9 120]]
# Epoch 58/99
# ----------
# train Loss: 0.3525 Acc: 0.8441
# val Loss: 0.5296 Acc: 0.7169
# Confusion Matrix:
# [[ 54  46   3]
#  [ 26  65   7]
#  [  2  10 119]]
# Epoch 59/99
# ----------
# train Loss: 0.3585 Acc: 0.8449
# val Loss: 0.5259 Acc: 0.7169
# Confusion Matrix:
# [[ 54  45   4]
#  [ 26  65   7]
#  [  2  10 119]]
# Epoch 60/99
# ----------
# train Loss: 0.3685 Acc: 0.8268
# val Loss: 0.5197 Acc: 0.7229
# Confusion Matrix:
# [[ 52  47   4]
#  [ 24  67   7]
#  [  2   8 121]]
# Epoch 61/99
# ----------
# train Loss: 0.3562 Acc: 0.8419
# val Loss: 0.5250 Acc: 0.7199
# Confusion Matrix:
# [[ 54  45   4]
#  [ 26  65   7]
#  [  2   9 120]]
# Epoch 62/99
# ----------
# train Loss: 0.3627 Acc: 0.8366
# val Loss: 0.5346 Acc: 0.7169
# Confusion Matrix:
# [[ 54  46   3]
#  [ 26  66   6]
#  [  3  10 118]]
# Epoch 63/99
# ----------
# train Loss: 0.3693 Acc: 0.8298
# val Loss: 0.5241 Acc: 0.7229
# Confusion Matrix:
# [[ 54  46   3]
#  [ 24  67   7]
#  [  2  10 119]]
# Epoch 64/99
# ----------
# train Loss: 0.3494 Acc: 0.8381
# val Loss: 0.5291 Acc: 0.7199
# Confusion Matrix:
# [[ 53  47   3]
#  [ 24  67   7]
#  [  2  10 119]]
# Epoch 65/99
# ----------
# train Loss: 0.3588 Acc: 0.8321
# val Loss: 0.5328 Acc: 0.7139
# Confusion Matrix:
# [[ 54  45   4]
#  [ 26  65   7]
#  [  3  10 118]]
# Epoch 66/99
# ----------
# train Loss: 0.3495 Acc: 0.8494
# val Loss: 0.5203 Acc: 0.7349
# Confusion Matrix:
# [[ 57  42   4]
#  [ 25  66   7]
#  [  2   8 121]]
# Epoch 67/99
# ----------
# train Loss: 0.3578 Acc: 0.8426
# val Loss: 0.5250 Acc: 0.7229
# Confusion Matrix:
# [[ 54  46   3]
#  [ 24  67   7]
#  [  2  10 119]]
# Epoch 68/99
# ----------
# train Loss: 0.3594 Acc: 0.8313
# val Loss: 0.5214 Acc: 0.7319
# Confusion Matrix:
# [[ 57  44   2]
#  [ 26  65   7]
#  [  2   8 121]]
# Epoch 69/99
# ----------
# train Loss: 0.3640 Acc: 0.8373
# val Loss: 0.5294 Acc: 0.7139
# Confusion Matrix:
# [[ 54  45   4]
#  [ 27  64   7]
#  [  2  10 119]]
# Epoch 70/99
# ----------
# train Loss: 0.3527 Acc: 0.8434
# val Loss: 0.5203 Acc: 0.7259
# Confusion Matrix:
# [[ 55  44   4]
#  [ 26  65   7]
#  [  2   8 121]]
# Epoch 71/99
# ----------
# train Loss: 0.3446 Acc: 0.8426
# val Loss: 0.5226 Acc: 0.7319
# Confusion Matrix:
# [[ 57  43   3]
#  [ 25  66   7]
#  [  2   9 120]]
# Epoch 72/99
# ----------
# train Loss: 0.3543 Acc: 0.8562
# val Loss: 0.5262 Acc: 0.7229
# Confusion Matrix:
# [[ 54  45   4]
#  [ 24  67   7]
#  [  2  10 119]]
# Epoch 73/99
# ----------
# train Loss: 0.3554 Acc: 0.8449
# val Loss: 0.5237 Acc: 0.7199
# Confusion Matrix:
# [[ 53  47   3]
#  [ 25  66   7]
#  [  2   9 120]]
# Epoch 74/99
# ----------
# train Loss: 0.3609 Acc: 0.8411
# val Loss: 0.5266 Acc: 0.7199
# Confusion Matrix:
# [[ 54  45   4]
#  [ 26  65   7]
#  [  2   9 120]]
# Epoch 75/99
# ----------
# train Loss: 0.3653 Acc: 0.8358
# val Loss: 0.5268 Acc: 0.7169
# Confusion Matrix:
# [[ 54  46   3]
#  [ 25  66   7]
#  [  3  10 118]]
# Epoch 76/99
# ----------
# train Loss: 0.3535 Acc: 0.8426
# val Loss: 0.5263 Acc: 0.7259
# Confusion Matrix:
# [[ 54  45   4]
#  [ 24  67   7]
#  [  2   9 120]]
# Epoch 77/99
# ----------
# train Loss: 0.3665 Acc: 0.8426
# val Loss: 0.5270 Acc: 0.7259
# Confusion Matrix:
# [[ 54  45   4]
#  [ 23  68   7]
#  [  2  10 119]]
# Epoch 78/99
# ----------
# train Loss: 0.3629 Acc: 0.8261
# val Loss: 0.5265 Acc: 0.7169
# Confusion Matrix:
# [[ 54  46   3]
#  [ 26  65   7]
#  [  2  10 119]]
# Epoch 79/99
# ----------
# train Loss: 0.3616 Acc: 0.8389
# val Loss: 0.5311 Acc: 0.7169
# Confusion Matrix:
# [[ 56  44   3]
#  [ 27  64   7]
#  [  3  10 118]]
# Epoch 80/99
# ----------
# train Loss: 0.3670 Acc: 0.8411
# val Loss: 0.5296 Acc: 0.7139
# Confusion Matrix:
# [[ 54  46   3]
#  [ 27  64   7]
#  [  2  10 119]]
# Epoch 81/99
# ----------
# train Loss: 0.3550 Acc: 0.8524
# val Loss: 0.5261 Acc: 0.7169
# Confusion Matrix:
# [[ 54  45   4]
#  [ 27  64   7]
#  [  2   9 120]]
# Epoch 82/99
# ----------
# train Loss: 0.3491 Acc: 0.8509
# val Loss: 0.5221 Acc: 0.7229
# Confusion Matrix:
# [[ 53  46   4]
#  [ 23  68   7]
#  [  2  10 119]]
# Epoch 83/99
# ----------
# train Loss: 0.3496 Acc: 0.8441
# val Loss: 0.5233 Acc: 0.7319
# Confusion Matrix:
# [[ 54  46   3]
#  [ 23  68   7]
#  [  2   8 121]]
# Epoch 84/99
# ----------
# train Loss: 0.3441 Acc: 0.8517
# val Loss: 0.5238 Acc: 0.7289
# Confusion Matrix:
# [[ 54  45   4]
#  [ 23  68   7]
#  [  2   9 120]]
# Epoch 85/99
# ----------
# train Loss: 0.3570 Acc: 0.8456
# val Loss: 0.5288 Acc: 0.7139
# Confusion Matrix:
# [[ 54  45   4]
#  [ 26  65   7]
#  [  3  10 118]]
# Epoch 86/99
# ----------
# train Loss: 0.3486 Acc: 0.8577
# val Loss: 0.5232 Acc: 0.7199
# Confusion Matrix:
# [[ 54  45   4]
#  [ 26  65   7]
#  [  2   9 120]]
# Epoch 87/99
# ----------
# train Loss: 0.3649 Acc: 0.8336
# val Loss: 0.5280 Acc: 0.7169
# Confusion Matrix:
# [[ 54  45   4]
#  [ 26  65   7]
#  [  2  10 119]]
# Epoch 88/99
# ----------
# train Loss: 0.3638 Acc: 0.8411
# val Loss: 0.5312 Acc: 0.7169
# Confusion Matrix:
# [[ 54  46   3]
#  [ 27  64   7]
#  [  2   9 120]]
# Epoch 89/99
# ----------
# train Loss: 0.3563 Acc: 0.8419
# val Loss: 0.5258 Acc: 0.7229
# Confusion Matrix:
# [[ 53  47   3]
#  [ 24  67   7]
#  [  2   9 120]]
# Epoch 90/99
# ----------
# train Loss: 0.3521 Acc: 0.8373
# val Loss: 0.5220 Acc: 0.7259
# Confusion Matrix:
# [[ 54  45   4]
#  [ 24  67   7]
#  [  2   9 120]]
# Epoch 91/99
# ----------
# train Loss: 0.3488 Acc: 0.8434
# val Loss: 0.5256 Acc: 0.7169
# Confusion Matrix:
# [[ 54  46   3]
#  [ 27  64   7]
#  [  2   9 120]]
# Epoch 92/99
# ----------
# train Loss: 0.3477 Acc: 0.8441
# val Loss: 0.5257 Acc: 0.7169
# Confusion Matrix:
# [[ 54  46   3]
#  [ 27  64   7]
#  [  2   9 120]]
# Epoch 93/99
# ----------
# train Loss: 0.3554 Acc: 0.8471
# val Loss: 0.5272 Acc: 0.7199
# Confusion Matrix:
# [[ 54  45   4]
#  [ 25  66   7]
#  [  2  10 119]]
# Epoch 94/99
# ----------
# train Loss: 0.3686 Acc: 0.8336
# val Loss: 0.5266 Acc: 0.7139
# Confusion Matrix:
# [[ 54  46   3]
#  [ 27  64   7]
#  [  2  10 119]]
# Epoch 95/99
# ----------
# train Loss: 0.3685 Acc: 0.8336
# val Loss: 0.5232 Acc: 0.7229
# Confusion Matrix:
# [[ 56  43   4]
#  [ 27  64   7]
#  [  2   9 120]]
# Epoch 96/99
# ----------
# train Loss: 0.3464 Acc: 0.8509
# val Loss: 0.5271 Acc: 0.7139
# Confusion Matrix:
# [[ 54  45   4]
#  [ 27  64   7]
#  [  2  10 119]]
# Epoch 97/99
# ----------
# train Loss: 0.3627 Acc: 0.8291
# val Loss: 0.5239 Acc: 0.7229
# Confusion Matrix:
# [[ 53  47   3]
#  [ 24  67   7]
#  [  2   9 120]]
# Epoch 98/99
# ----------
# train Loss: 0.3642 Acc: 0.8230
# val Loss: 0.5293 Acc: 0.7169
# Confusion Matrix:
# [[ 54  46   3]
#  [ 26  65   7]
#  [  2  10 119]]
# Epoch 99/99
# ----------
# train Loss: 0.3589 Acc: 0.8411
# val Loss: 0.5249 Acc: 0.7229
# Confusion Matrix:
# [[ 56  43   4]
#  [ 27  64   7]
#  [  2   9 120]]
# Training complete in 0m 49s
# Best val Acc: 0.743976

# %%
plot_loss_with_MyModel(finetuned_MyModel, plot_title = "CNN Model")

# %%
plot_cm_with_MyModel(MyModel_here = finetuned_MyModel, plot_title = "CNN Model")

# %%
torch.save(finetuned_MyModel.model, './model/EarthquakeCNN_finetuned.pth')
