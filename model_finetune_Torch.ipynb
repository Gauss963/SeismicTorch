# %%
import copy
import torch
import time
import os

import torch.optim as optim
import torch.nn as nn
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from torch.utils.data import DataLoader
from torch.utils.data import Dataset
from torch.optim import lr_scheduler
from sklearn.metrics import confusion_matrix
from sklearn.model_selection import train_test_split
from def_model import EarthquakeCNN

import functions

# %%
class EarthquakeDataset(Dataset):
    def __init__(self, features, labels):
        self.features = features
        self.labels = labels

    def __len__(self):
        return len(self.features)

    def __getitem__(self, idx):
        return self.features[idx], self.labels[idx]

# %%
datadir = './data_QSIS_pth'

train_data_path = os.path.join(datadir, "all_merged.pth")
train_data = torch.load(train_data_path)
Xall = train_data['Xall']
Yall = train_data['Yall']

# %%
Xall, Yall = functions.remove_small_amplitude(Xall, Yall) 
Xall, Yall = functions.remove_large_amplitude(Xall, Yall)
log10_amplitude = np.log10(np.max(np.abs(Xall), axis = (1, 2, 3)))
Xall = functions.normalize(Xall)
Xall = functions.quantize(Xall)
Xall = Xall.astype(np.float32)
Xall = functions.normalize(Xall)

# %%
Xall = torch.from_numpy(Xall).float()
Yall = torch.from_numpy(Yall).float()

Xall = Xall.permute(0, 3, 1, 2)

# %%
# split the data into training and validation datasets
X_train, X_val, Y_train, Y_val = train_test_split(Xall, Yall, test_size = 0.2, random_state = 42)

# create datasets
train_dataset = EarthquakeDataset(X_train, Y_train)
val_dataset = EarthquakeDataset(X_val, Y_val)

# create dataloaders
train_dataloader = DataLoader(train_dataset, batch_size = 32, shuffle = True)
val_dataloader = DataLoader(val_dataset, batch_size = 32, shuffle = True)

# put dataloaders into a dictionary
dataloaders = {
    'train': train_dataloader,
    'val': val_dataloader
}

# similarly, create a dictionary for dataset sizes
dataset_sizes = {
    'train': len(train_dataset),
    'val': len(val_dataset)
}

# %%
print(X_train.shape)
print(Y_train.shape)
# Out:
# torch.Size([1325, 1, 80, 3])
# torch.Size([1325, 3])

# %%
class MyModel:
    def __init__(self, model, epoch_arr, train_loss_arr, val_loss_arr, train_acc_arr, val_acc_arr, lr_arr, cm, best_acc):
        self.model = model
        self.epoch_arr = epoch_arr
        self.train_loss_arr = train_loss_arr
        self.val_loss_arr = val_loss_arr
        self.train_acc_arr = train_acc_arr
        self.val_acc_arr = val_acc_arr
        self.lr_arr = lr_arr
        self.cm = cm
        self.best_acc = best_acc

# %%
def plot_loss_with_MyModel(MyModel_here, plot_title = "Default"):
    epoch_arr_here = MyModel_here.epoch_arr
    train_loss_arr_here = MyModel_here.train_loss_arr
    val_loss_arr_here = MyModel_here.val_loss_arr
    train_acc_arr_here = MyModel_here.train_acc_arr
    val_acc_arr_here = MyModel_here.val_acc_arr
    lr_arr_here = MyModel_here.lr_arr

    fig_loss_func, axes_loss_func = plt.subplots(nrows = 1, ncols = 3, figsize = (24, 6))
    fig_loss_func.suptitle(plot_title)

    axes_loss_func[0].plot(epoch_arr_here, train_loss_arr_here, label = 'Training Loss')
    axes_loss_func[0].plot(epoch_arr_here, val_loss_arr_here, label = 'Validation Loss')
    axes_loss_func[0].set_title('Loss')
    axes_loss_func[0].set_xlabel('Epoch')
    axes_loss_func[0].set_ylabel('Loss')
    axes_loss_func[0].legend()
    axes_loss_func[1].plot(epoch_arr_here, train_acc_arr_here, label = 'Training Accuracy')
    axes_loss_func[1].plot(epoch_arr_here, val_acc_arr_here, label = 'Validation Accuracy')
    axes_loss_func[1].set_title('Accuracy')
    axes_loss_func[1].set_xlabel('Epoch')
    axes_loss_func[1].set_ylabel('Accurracy')
    axes_loss_func[1].legend()
    axes_loss_func[2].plot(epoch_arr_here, lr_arr_here, label = 'Learning Rate')
    axes_loss_func[2].set_title('Learning Rate')
    axes_loss_func[2].set_xlabel('Epoch')
    axes_loss_func[2].set_ylabel('Accuracy')
    axes_loss_func[2].legend()
    fig_loss_func.tight_layout()
    plt.savefig('./Result_Finetuing/Accurracy.pdf')

# %%
def plot_cm_with_MyModel(MyModel_here, plot_title = "Default"):

    cm_here = MyModel_here.cm
    cm_here = cm_here.astype('float') / cm_here.sum(axis = 1)[:, np.newaxis]

    labels = ['P-wave', 'S-wave', 'Noise']
    cm_here_df = pd.DataFrame(cm_here, index = labels, columns = labels)
    cm_here = cm_here_df

    fig_cm_func, axes_cm_func = plt.subplots(nrows = 1, ncols = 1, figsize = (8, 6))
    acc_here = MyModel_here.best_acc.detach().cpu().numpy() * 100
    acc_here = round(acc_here, 2)
    fig_cm_func.suptitle(plot_title + ' Confusion Matrix, Accuracy = ' + str(acc_here) + '%')

    sns.heatmap(cm_here, annot = True, cmap = 'Blues', ax = axes_cm_func)
    axes_cm_func.set_title('Train Confusion Matrix')
    axes_cm_func.set_xlabel('Predicted Labels')
    axes_cm_func.set_ylabel('Actual Labels')
    fig_cm_func.tight_layout()

    plt.savefig('./Result_Finetuing/Confusion_Matrix.pdf')

# %%
def train_model(model, criterion, optimizer, scheduler, num_epochs = 25):
    since = time.time()

    best_model_wts = copy.deepcopy(model.state_dict())
    best_acc = 0.0

    epoch_arr = np.array([])
    lr_arr = np.array([])
    train_loss_arr = np.array([])
    train_acc_arr = np.array([])

    val_loss_arr = np.array([])
    val_acc_arr = np.array([])

    for epoch in range(num_epochs):
        print(f'Epoch {epoch}/{num_epochs - 1}')
        print('-' * 10)

        # Each epoch has a training and validation phase
        for phase in ['train', 'val']:
            if phase == 'train':
                model.train()  # Set model to training mode
            else:
                model.eval()   # Set model to evaluate mode

            running_loss = 0.0
            running_corrects = 0

            # These lists will hold all labels and predictions for this epoch
            # all_labels = []
            # all_preds = []

            all_labels = np.array([])
            all_preds = np.array([])

            # Iterate over data.
            for inputs, labels in dataloaders[phase]:
                inputs = inputs
                labels = labels

                # zero the parameter gradients
                optimizer.zero_grad()

                # forward
                # track history if only in train
                with torch.set_grad_enabled(phase == 'train'):
                    outputs = model(inputs)
                    _, preds = torch.max(outputs, 1)
                    _, labels = torch.max(labels.data, 1)
                    loss = criterion(outputs, labels)

                    # backward + optimize only if in training phase
                    if phase == 'train':
                        loss.backward()
                        optimizer.step()

                # statistics
                running_loss += loss.item() * inputs.size(0)
                running_corrects += torch.sum(preds == labels.data)

                # Add current labels and predictions to the lists
                # all_labels.extend(labels.tolist())
                # all_preds.extend(preds.tolist())

                all_labels = np.append(all_labels, labels.tolist())
                all_preds = np.append(all_preds, preds.tolist())

            if phase == 'train':
                scheduler.step()

            epoch_loss = running_loss / dataset_sizes[phase]
            epoch_acc = running_corrects / dataset_sizes[phase]

            print(f'{phase} Loss: {epoch_loss:.4f} Acc: {epoch_acc:.4f}')

            # After each epoch, compute and print the confusion matrix
            if phase == 'val':
                print("Confusion Matrix:")
                cm_here = confusion_matrix(all_labels, all_preds)
                print(cm_here)

            # save the loss and accurracy
            if phase == 'train':
                train_loss_arr = np.append(train_loss_arr, epoch_loss)
                train_acc_arr = np.append(train_acc_arr, epoch_acc.detach().cpu())
                lr_arr = np.append(lr_arr, optimizer.param_groups[0]['lr'])
                epoch_arr = np.append(epoch_arr, epoch)
            elif phase == 'val':
                val_loss_arr = np.append(val_loss_arr, epoch_loss)
                val_acc_arr = np.append(val_acc_arr, epoch_acc.detach().cpu())

            # deep copy the model
            if phase == 'val' and epoch_acc > best_acc:
                best_acc = epoch_acc
                best_model_wts = copy.deepcopy(model.state_dict())

    time_elapsed = time.time() - since
    print(f'Training complete in {time_elapsed // 60:.0f}m {time_elapsed % 60:.0f}s')
    print(f'Best val Acc: {best_acc:4f}')

    # load best model weights
    model.load_state_dict(best_model_wts)

    model_class = MyModel(model = model, 
                          epoch_arr = epoch_arr, 
                          train_loss_arr = train_loss_arr, 
                          val_loss_arr = val_loss_arr, 
                          train_acc_arr = train_acc_arr, 
                          val_acc_arr = val_acc_arr, 
                          lr_arr = lr_arr, 
                          cm = cm_here, 
                          best_acc = best_acc)

    return model_class

# %%
model = torch.load('./model/EarthquakeCNN.pth')
# model = EarthquakeCNN()

# 凍結模型的卷積層
for param in model.parameters():
    # param.requires_grad = False
    param.requires_grad = True

# 全連接層的權重將被更新
for param in model.fc1.parameters():
    param.requires_grad = True
for param in model.fc2.parameters():
    param.requires_grad = True
for param in model.fc3.parameters():
    param.requires_grad = True

# %%
criterion = nn.CrossEntropyLoss()

# 使用Adam優化器，並且設定學習率為0.001
# optimizer = optim.Adam(model.parameters(), lr = 0.001)
optimizer = optim.AdamW(model.parameters(), lr = 0.001)
# optimizer = optim.RAdam(model.parameters(), lr = 0.001)

# 每7個epoch，學習率減半
exp_lr_scheduler = lr_scheduler.StepLR(optimizer, step_size = 7, gamma = 0.5)

# %%
finetuned_MyModel = train_model(model, criterion, optimizer, exp_lr_scheduler, num_epochs = 100)
# Out:
# Epoch 0/99
# ----------
# train Loss: 1.6963 Acc: 0.4060
# val Loss: 0.8782 Acc: 0.5090
# Confusion Matrix:
# [[55 31 17]
#  [44 33 21]
#  [23 27 81]]
# Epoch 1/99
# ----------
# train Loss: 0.8212 Acc: 0.5849
# val Loss: 0.7700 Acc: 0.6114
# Confusion Matrix:
# [[ 50  39  14]
#  [ 34  47  17]
#  [ 11  14 106]]
# Epoch 2/99
# ----------
# train Loss: 0.7098 Acc: 0.6664
# val Loss: 0.6847 Acc: 0.6687
# Confusion Matrix:
# [[ 62  28  13]
#  [ 42  36  20]
#  [  5   2 124]]
# Epoch 3/99
# ----------
# train Loss: 0.6486 Acc: 0.6808
# val Loss: 0.6518 Acc: 0.6988
# Confusion Matrix:
# [[ 63  31   9]
#  [ 40  47  11]
#  [  6   3 122]]
# Epoch 4/99
# ----------
# train Loss: 0.5945 Acc: 0.6989
# val Loss: 0.6372 Acc: 0.7139
# Confusion Matrix:
# [[ 80  19   4]
#  [ 53  41   4]
#  [  6   9 116]]
# Epoch 5/99
# ----------
# train Loss: 0.5763 Acc: 0.7155
# val Loss: 0.5964 Acc: 0.7078
# Confusion Matrix:
# [[ 67  30   6]
#  [ 43  46   9]
#  [  4   5 122]]
# Epoch 6/99
# ----------
# train Loss: 0.5455 Acc: 0.7260
# val Loss: 0.5879 Acc: 0.6898
# Confusion Matrix:
# [[ 46  49   8]
#  [ 30  62   6]
#  [  1   9 121]]
# Epoch 7/99
# ----------
# train Loss: 0.5132 Acc: 0.7366
# val Loss: 0.5813 Acc: 0.7048
# Confusion Matrix:
# [[ 66  32   5]
#  [ 44  49   5]
#  [  7   5 119]]
# Epoch 8/99
# ----------
# train Loss: 0.5035 Acc: 0.7351
# val Loss: 0.5886 Acc: 0.7048
# Confusion Matrix:
# [[ 61  37   5]
#  [ 40  56   2]
#  [  5   9 117]]
# Epoch 9/99
# ----------
# train Loss: 0.5017 Acc: 0.7494
# val Loss: 0.5810 Acc: 0.7018
# Confusion Matrix:
# [[ 67  30   6]
#  [ 46  48   4]
#  [  9   4 118]]
# Epoch 10/99
# ----------
# train Loss: 0.4750 Acc: 0.7585
# val Loss: 0.5726 Acc: 0.7018
# Confusion Matrix:
# [[ 70  27   6]
#  [ 50  44   4]
#  [  9   3 119]]
# Epoch 11/99
# ----------
# train Loss: 0.4676 Acc: 0.7668
# val Loss: 0.5895 Acc: 0.6837
# Confusion Matrix:
# [[ 51  45   7]
#  [ 36  60   2]
#  [  4  11 116]]
# Epoch 12/99
# ----------
# train Loss: 0.4639 Acc: 0.7698
# val Loss: 0.5706 Acc: 0.6958
# Confusion Matrix:
# [[ 60  39   4]
#  [ 43  52   3]
#  [  8   4 119]]
# Epoch 13/99
# ----------
# train Loss: 0.4593 Acc: 0.7623
# val Loss: 0.5887 Acc: 0.6958
# Confusion Matrix:
# [[ 70  29   4]
#  [ 52  44   2]
#  [ 10   4 117]]
# Epoch 14/99
# ----------
# train Loss: 0.4238 Acc: 0.7992
# val Loss: 0.5764 Acc: 0.7018
# Confusion Matrix:
# [[ 67  31   5]
#  [ 46  49   3]
#  [ 10   4 117]]
# Epoch 15/99
# ----------
# train Loss: 0.4241 Acc: 0.7940
# val Loss: 0.5697 Acc: 0.7139
# Confusion Matrix:
# [[ 63  35   5]
#  [ 42  54   2]
#  [  6   5 120]]
# Epoch 16/99
# ----------
# train Loss: 0.4465 Acc: 0.7864
# val Loss: 0.5815 Acc: 0.7048
# Confusion Matrix:
# [[ 62  36   5]
#  [ 43  53   2]
#  [  7   5 119]]
# Epoch 17/99
# ----------
# train Loss: 0.4094 Acc: 0.8083
# val Loss: 0.5813 Acc: 0.6928
# Confusion Matrix:
# [[ 63  36   4]
#  [ 45  51   2]
#  [  8   7 116]]
# Epoch 18/99
# ----------
# train Loss: 0.4153 Acc: 0.8030
# val Loss: 0.5795 Acc: 0.7018
# Confusion Matrix:
# [[ 65  35   3]
#  [ 46  50   2]
#  [  7   6 118]]
# Epoch 19/99
# ----------
# train Loss: 0.4100 Acc: 0.7887
# val Loss: 0.5702 Acc: 0.7018
# Confusion Matrix:
# [[ 61  38   4]
#  [ 43  53   2]
#  [  7   5 119]]
# Epoch 20/99
# ----------
# train Loss: 0.4011 Acc: 0.8045
# val Loss: 0.5666 Acc: 0.6958
# Confusion Matrix:
# [[ 50  46   7]
#  [ 34  61   3]
#  [  4   7 120]]
# Epoch 21/99
# ----------
# train Loss: 0.3942 Acc: 0.8045
# val Loss: 0.5736 Acc: 0.6988
# Confusion Matrix:
# [[ 62  35   6]
#  [ 41  53   4]
#  [  6   8 117]]
# Epoch 22/99
# ----------
# train Loss: 0.3938 Acc: 0.8121
# val Loss: 0.5637 Acc: 0.7018
# Confusion Matrix:
# [[ 63  34   6]
#  [ 45  52   1]
#  [  7   6 118]]
# Epoch 23/99
# ----------
# train Loss: 0.3962 Acc: 0.8053
# val Loss: 0.5628 Acc: 0.7018
# Confusion Matrix:
# [[ 59  38   6]
#  [ 42  55   1]
#  [  5   7 119]]
# Epoch 24/99
# ----------
# train Loss: 0.3859 Acc: 0.8128
# val Loss: 0.5727 Acc: 0.6988
# Confusion Matrix:
# [[ 65  34   4]
#  [ 46  51   1]
#  [  8   7 116]]
# Epoch 25/99
# ----------
# train Loss: 0.3848 Acc: 0.8143
# val Loss: 0.5623 Acc: 0.7048
# Confusion Matrix:
# [[ 58  40   5]
#  [ 40  57   1]
#  [  5   7 119]]
# Epoch 26/99
# ----------
# train Loss: 0.3836 Acc: 0.8226
# val Loss: 0.5655 Acc: 0.7108
# Confusion Matrix:
# [[ 56  42   5]
#  [ 35  61   2]
#  [  5   7 119]]
# Epoch 27/99
# ----------
# train Loss: 0.3738 Acc: 0.8174
# val Loss: 0.5679 Acc: 0.6928
# Confusion Matrix:
# [[ 59  40   4]
#  [ 43  53   2]
#  [  6   7 118]]
# Epoch 28/99
# ----------
# train Loss: 0.3654 Acc: 0.8309
# val Loss: 0.5664 Acc: 0.7018
# Confusion Matrix:
# [[ 62  37   4]
#  [ 44  53   1]
#  [  8   5 118]]
# Epoch 29/99
# ----------
# train Loss: 0.3803 Acc: 0.8234
# val Loss: 0.5661 Acc: 0.7078
# Confusion Matrix:
# [[ 58  39   6]
#  [ 38  58   2]
#  [  6   6 119]]
# Epoch 30/99
# ----------
# train Loss: 0.3643 Acc: 0.8272
# val Loss: 0.5638 Acc: 0.7018
# Confusion Matrix:
# [[ 56  42   5]
#  [ 37  59   2]
#  [  6   7 118]]
# Epoch 31/99
# ----------
# train Loss: 0.3768 Acc: 0.8272
# val Loss: 0.5659 Acc: 0.6958
# Confusion Matrix:
# [[ 54  43   6]
#  [ 36  60   2]
#  [  6   8 117]]
# Epoch 32/99
# ----------
# train Loss: 0.3738 Acc: 0.8325
# val Loss: 0.5710 Acc: 0.7018
# Confusion Matrix:
# [[ 62  38   3]
#  [ 42  54   2]
#  [  6   8 117]]
# Epoch 33/99
# ----------
# train Loss: 0.3634 Acc: 0.8370
# val Loss: 0.5682 Acc: 0.6958
# Confusion Matrix:
# [[ 60  39   4]
#  [ 42  54   2]
#  [  8   6 117]]
# Epoch 34/99
# ----------
# train Loss: 0.3619 Acc: 0.8370
# val Loss: 0.5742 Acc: 0.6988
# Confusion Matrix:
# [[ 63  34   6]
#  [ 43  53   2]
#  [  8   7 116]]
# Epoch 35/99
# ----------
# train Loss: 0.3619 Acc: 0.8317
# val Loss: 0.5704 Acc: 0.7018
# Confusion Matrix:
# [[ 59  39   5]
#  [ 39  57   2]
#  [  6   8 117]]
# Epoch 36/99
# ----------
# train Loss: 0.3575 Acc: 0.8287
# val Loss: 0.5746 Acc: 0.6988
# Confusion Matrix:
# [[ 63  37   3]
#  [ 44  53   1]
#  [  7   8 116]]
# Epoch 37/99
# ----------
# train Loss: 0.3620 Acc: 0.8332
# val Loss: 0.5670 Acc: 0.6958
# Confusion Matrix:
# [[ 58  40   5]
#  [ 40  56   2]
#  [  6   8 117]]
# Epoch 38/99
# ----------
# train Loss: 0.3582 Acc: 0.8325
# val Loss: 0.5770 Acc: 0.7048
# Confusion Matrix:
# [[ 59  40   4]
#  [ 38  59   1]
#  [  6   9 116]]
# Epoch 39/99
# ----------
# train Loss: 0.3514 Acc: 0.8415
# val Loss: 0.5640 Acc: 0.6928
# Confusion Matrix:
# [[ 56  40   7]
#  [ 37  57   4]
#  [  6   8 117]]
# Epoch 40/99
# ----------
# train Loss: 0.3604 Acc: 0.8211
# val Loss: 0.5626 Acc: 0.7048
# Confusion Matrix:
# [[ 61  36   6]
#  [ 42  55   1]
#  [  6   7 118]]
# Epoch 41/99
# ----------
# train Loss: 0.3672 Acc: 0.8362
# val Loss: 0.5733 Acc: 0.7018
# Confusion Matrix:
# [[ 60  38   5]
#  [ 41  56   1]
#  [  6   8 117]]
# Epoch 42/99
# ----------
# train Loss: 0.3579 Acc: 0.8385
# val Loss: 0.5732 Acc: 0.7048
# Confusion Matrix:
# [[ 62  36   5]
#  [ 42  55   1]
#  [  6   8 117]]
# Epoch 43/99
# ----------
# train Loss: 0.3636 Acc: 0.8264
# val Loss: 0.5649 Acc: 0.6988
# Confusion Matrix:
# [[ 59  39   5]
#  [ 41  56   1]
#  [  6   8 117]]
# Epoch 44/99
# ----------
# train Loss: 0.3457 Acc: 0.8400
# val Loss: 0.5731 Acc: 0.7139
# Confusion Matrix:
# [[ 65  34   4]
#  [ 42  55   1]
#  [  6   8 117]]
# Epoch 45/99
# ----------
# train Loss: 0.3579 Acc: 0.8332
# val Loss: 0.5727 Acc: 0.7018
# Confusion Matrix:
# [[ 59  39   5]
#  [ 39  58   1]
#  [  6   9 116]]
# Epoch 46/99
# ----------
# train Loss: 0.3604 Acc: 0.8483
# val Loss: 0.5677 Acc: 0.7078
# Confusion Matrix:
# [[ 62  38   3]
#  [ 41  56   1]
#  [  6   8 117]]
# Epoch 47/99
# ----------
# train Loss: 0.3580 Acc: 0.8332
# val Loss: 0.5731 Acc: 0.7108
# Confusion Matrix:
# [[ 62  38   3]
#  [ 39  58   1]
#  [  6   9 116]]
# Epoch 48/99
# ----------
# train Loss: 0.3488 Acc: 0.8445
# val Loss: 0.5743 Acc: 0.7108
# Confusion Matrix:
# [[ 64  36   3]
#  [ 42  55   1]
#  [  6   8 117]]
# Epoch 49/99
# ----------
# train Loss: 0.3704 Acc: 0.8272
# val Loss: 0.5701 Acc: 0.7078
# Confusion Matrix:
# [[ 59  39   5]
#  [ 38  59   1]
#  [  6   8 117]]
# Epoch 50/99
# ----------
# train Loss: 0.3420 Acc: 0.8460
# val Loss: 0.5788 Acc: 0.7018
# Confusion Matrix:
# [[ 62  37   4]
#  [ 42  55   1]
#  [  6   9 116]]
# Epoch 51/99
# ----------
# train Loss: 0.3574 Acc: 0.8370
# val Loss: 0.5774 Acc: 0.7018
# Confusion Matrix:
# [[ 61  38   4]
#  [ 41  56   1]
#  [  6   9 116]]
# Epoch 52/99
# ----------
# train Loss: 0.3481 Acc: 0.8408
# val Loss: 0.5696 Acc: 0.7018
# Confusion Matrix:
# [[ 58  40   5]
#  [ 37  59   2]
#  [  6   9 116]]
# Epoch 53/99
# ----------
# train Loss: 0.3519 Acc: 0.8340
# val Loss: 0.5670 Acc: 0.7139
# Confusion Matrix:
# [[ 63  37   3]
#  [ 40  57   1]
#  [  6   8 117]]
# Epoch 54/99
# ----------
# train Loss: 0.3401 Acc: 0.8498
# val Loss: 0.5698 Acc: 0.7078
# Confusion Matrix:
# [[ 62  38   3]
#  [ 41  56   1]
#  [  6   8 117]]
# Epoch 55/99
# ----------
# train Loss: 0.3570 Acc: 0.8355
# val Loss: 0.5720 Acc: 0.7018
# Confusion Matrix:
# [[ 61  38   4]
#  [ 41  56   1]
#  [  6   9 116]]
# Epoch 56/99
# ----------
# train Loss: 0.3560 Acc: 0.8438
# val Loss: 0.5733 Acc: 0.7108
# Confusion Matrix:
# [[ 63  37   3]
#  [ 40  57   1]
#  [  6   9 116]]
# Epoch 57/99
# ----------
# train Loss: 0.3529 Acc: 0.8392
# val Loss: 0.5717 Acc: 0.7048
# Confusion Matrix:
# [[ 62  38   3]
#  [ 41  56   1]
#  [  6   9 116]]
# Epoch 58/99
# ----------
# train Loss: 0.3454 Acc: 0.8491
# val Loss: 0.5717 Acc: 0.7048
# Confusion Matrix:
# [[ 58  40   5]
#  [ 37  60   1]
#  [  6   9 116]]
# Epoch 59/99
# ----------
# train Loss: 0.3459 Acc: 0.8423
# val Loss: 0.5719 Acc: 0.7108
# Confusion Matrix:
# [[ 59  40   4]
#  [ 36  61   1]
#  [  6   9 116]]
# Epoch 60/99
# ----------
# train Loss: 0.3436 Acc: 0.8445
# val Loss: 0.5711 Acc: 0.7078
# Confusion Matrix:
# [[ 59  38   6]
#  [ 38  59   1]
#  [  6   8 117]]
# Epoch 61/99
# ----------
# train Loss: 0.3465 Acc: 0.8528
# val Loss: 0.5749 Acc: 0.7018
# Confusion Matrix:
# [[ 57  40   6]
#  [ 37  60   1]
#  [  7   8 116]]
# Epoch 62/99
# ----------
# train Loss: 0.3473 Acc: 0.8468
# val Loss: 0.5702 Acc: 0.7048
# Confusion Matrix:
# [[ 62  38   3]
#  [ 41  56   1]
#  [  6   9 116]]
# Epoch 63/99
# ----------
# train Loss: 0.3588 Acc: 0.8408
# val Loss: 0.5705 Acc: 0.7018
# Confusion Matrix:
# [[ 59  39   5]
#  [ 40  57   1]
#  [  7   7 117]]
# Epoch 64/99
# ----------
# train Loss: 0.3524 Acc: 0.8377
# val Loss: 0.5705 Acc: 0.7018
# Confusion Matrix:
# [[ 57  40   6]
#  [ 38  59   1]
#  [  7   7 117]]
# Epoch 65/99
# ----------
# train Loss: 0.3571 Acc: 0.8272
# val Loss: 0.5706 Acc: 0.7199
# Confusion Matrix:
# [[ 65  35   3]
#  [ 40  57   1]
#  [  6   8 117]]
# Epoch 66/99
# ----------
# train Loss: 0.3562 Acc: 0.8355
# val Loss: 0.5716 Acc: 0.6988
# Confusion Matrix:
# [[ 58  40   5]
#  [ 40  57   1]
#  [  6   8 117]]
# Epoch 67/99
# ----------
# train Loss: 0.3455 Acc: 0.8453
# val Loss: 0.5691 Acc: 0.7048
# Confusion Matrix:
# [[ 61  39   3]
#  [ 41  56   1]
#  [  6   8 117]]
# Epoch 68/99
# ----------
# train Loss: 0.3578 Acc: 0.8272
# val Loss: 0.5695 Acc: 0.6988
# Confusion Matrix:
# [[ 61  38   4]
#  [ 42  55   1]
#  [  6   9 116]]
# Epoch 69/99
# ----------
# train Loss: 0.3571 Acc: 0.8355
# val Loss: 0.5739 Acc: 0.7018
# Confusion Matrix:
# [[ 64  36   3]
#  [ 44  53   1]
#  [  6   9 116]]
# Epoch 70/99
# ----------
# train Loss: 0.3435 Acc: 0.8498
# val Loss: 0.5694 Acc: 0.7139
# Confusion Matrix:
# [[ 64  36   3]
#  [ 41  56   1]
#  [  6   8 117]]
# Epoch 71/99
# ----------
# train Loss: 0.3408 Acc: 0.8392
# val Loss: 0.5722 Acc: 0.6928
# Confusion Matrix:
# [[ 57  40   6]
#  [ 40  57   1]
#  [  7   8 116]]
# Epoch 72/99
# ----------
# train Loss: 0.3491 Acc: 0.8543
# val Loss: 0.5723 Acc: 0.7048
# Confusion Matrix:
# [[ 60  38   5]
#  [ 39  58   1]
#  [  6   9 116]]
# Epoch 73/99
# ----------
# train Loss: 0.3467 Acc: 0.8543
# val Loss: 0.5682 Acc: 0.7139
# Confusion Matrix:
# [[ 59  38   6]
#  [ 36  61   1]
#  [  6   8 117]]
# Epoch 74/99
# ----------
# train Loss: 0.3483 Acc: 0.8453
# val Loss: 0.5630 Acc: 0.7259
# Confusion Matrix:
# [[ 65  34   4]
#  [ 39  58   1]
#  [  7   6 118]]
# Epoch 75/99
# ----------
# train Loss: 0.3485 Acc: 0.8415
# val Loss: 0.5669 Acc: 0.7199
# Confusion Matrix:
# [[ 63  37   3]
#  [ 39  58   1]
#  [  6   7 118]]
# Epoch 76/99
# ----------
# train Loss: 0.3479 Acc: 0.8460
# val Loss: 0.5720 Acc: 0.7139
# Confusion Matrix:
# [[ 63  36   4]
#  [ 40  57   1]
#  [  6   8 117]]
# Epoch 77/99
# ----------
# train Loss: 0.3498 Acc: 0.8385
# val Loss: 0.5733 Acc: 0.6958
# Confusion Matrix:
# [[ 59  38   6]
#  [ 41  56   1]
#  [  7   8 116]]
# Epoch 78/99
# ----------
# train Loss: 0.3487 Acc: 0.8445
# val Loss: 0.5698 Acc: 0.7078
# Confusion Matrix:
# [[ 60  39   4]
#  [ 38  59   1]
#  [  6   9 116]]
# Epoch 79/99
# ----------
# train Loss: 0.3590 Acc: 0.8325
# val Loss: 0.5745 Acc: 0.7018
# Confusion Matrix:
# [[ 60  39   4]
#  [ 39  57   2]
#  [  7   8 116]]
# Epoch 80/99
# ----------
# train Loss: 0.3507 Acc: 0.8355
# val Loss: 0.5767 Acc: 0.6958
# Confusion Matrix:
# [[ 60  39   4]
#  [ 42  55   1]
#  [  6   9 116]]
# Epoch 81/99
# ----------
# train Loss: 0.3453 Acc: 0.8430
# val Loss: 0.5684 Acc: 0.7048
# Confusion Matrix:
# [[ 57  42   4]
#  [ 37  60   1]
#  [  6   8 117]]
# Epoch 82/99
# ----------
# train Loss: 0.3463 Acc: 0.8438
# val Loss: 0.5679 Acc: 0.7108
# Confusion Matrix:
# [[ 63  35   5]
#  [ 41  56   1]
#  [  7   7 117]]
# Epoch 83/99
# ----------
# train Loss: 0.3598 Acc: 0.8309
# val Loss: 0.5669 Acc: 0.7108
# Confusion Matrix:
# [[ 58  40   5]
#  [ 36  61   1]
#  [  6   8 117]]
# Epoch 84/99
# ----------
# train Loss: 0.3460 Acc: 0.8377
# val Loss: 0.5740 Acc: 0.6958
# Confusion Matrix:
# [[ 59  39   5]
#  [ 41  56   1]
#  [  7   8 116]]
# Epoch 85/99
# ----------
# train Loss: 0.3558 Acc: 0.8370
# val Loss: 0.5695 Acc: 0.7078
# Confusion Matrix:
# [[ 61  38   4]
#  [ 40  57   1]
#  [  6   8 117]]
# Epoch 86/99
# ----------
# train Loss: 0.3453 Acc: 0.8377
# val Loss: 0.5721 Acc: 0.7018
# Confusion Matrix:
# [[ 58  40   5]
#  [ 39  58   1]
#  [  7   7 117]]
# Epoch 87/99
# ----------
# train Loss: 0.3496 Acc: 0.8408
# val Loss: 0.5695 Acc: 0.7048
# Confusion Matrix:
# [[ 58  40   5]
#  [ 36  60   2]
#  [  6   9 116]]
# Epoch 88/99
# ----------
# train Loss: 0.3508 Acc: 0.8385
# val Loss: 0.5683 Acc: 0.7078
# Confusion Matrix:
# [[ 58  41   4]
#  [ 36  61   1]
#  [  6   9 116]]
# Epoch 89/99
# ----------
# train Loss: 0.3463 Acc: 0.8355
# val Loss: 0.5684 Acc: 0.7078
# Confusion Matrix:
# [[ 60  39   4]
#  [ 39  58   1]
#  [  6   8 117]]
# Epoch 90/99
# ----------
# train Loss: 0.3431 Acc: 0.8385
# val Loss: 0.5727 Acc: 0.7048
# Confusion Matrix:
# [[ 62  37   4]
#  [ 41  56   1]
#  [  6   9 116]]
# Epoch 91/99
# ----------
# train Loss: 0.3507 Acc: 0.8385
# val Loss: 0.5703 Acc: 0.7018
# Confusion Matrix:
# [[ 58  39   6]
#  [ 39  58   1]
#  [  7   7 117]]
# Epoch 92/99
# ----------
# train Loss: 0.3529 Acc: 0.8430
# val Loss: 0.5726 Acc: 0.7048
# Confusion Matrix:
# [[ 61  38   4]
#  [ 40  57   1]
#  [  6   9 116]]
# Epoch 93/99
# ----------
# train Loss: 0.3445 Acc: 0.8558
# val Loss: 0.5670 Acc: 0.7078
# Confusion Matrix:
# [[ 59  38   6]
#  [ 38  59   1]
#  [  7   7 117]]
# Epoch 94/99
# ----------
# train Loss: 0.3443 Acc: 0.8551
# val Loss: 0.5708 Acc: 0.7018
# Confusion Matrix:
# [[ 60  39   4]
#  [ 40  57   1]
#  [  6   9 116]]
# Epoch 95/99
# ----------
# train Loss: 0.3477 Acc: 0.8475
# val Loss: 0.5699 Acc: 0.7108
# Confusion Matrix:
# [[ 62  38   3]
#  [ 40  57   1]
#  [  6   8 117]]
# Epoch 96/99
# ----------
# train Loss: 0.3447 Acc: 0.8445
# val Loss: 0.5721 Acc: 0.7018
# Confusion Matrix:
# [[ 58  40   5]
#  [ 38  59   1]
#  [  6   9 116]]
# Epoch 97/99
# ----------
# train Loss: 0.3565 Acc: 0.8370
# val Loss: 0.5723 Acc: 0.7048
# Confusion Matrix:
# [[ 61  38   4]
#  [ 40  57   1]
#  [  6   9 116]]
# Epoch 98/99
# ----------
# train Loss: 0.3586 Acc: 0.8408
# val Loss: 0.5681 Acc: 0.7139
# Confusion Matrix:
# [[ 63  37   3]
#  [ 41  56   1]
#  [  6   7 118]]
# Epoch 99/99
# ----------
# train Loss: 0.3589 Acc: 0.8325
# val Loss: 0.5734 Acc: 0.7018
# Confusion Matrix:
# [[ 58  40   5]
#  [ 38  59   1]
#  [  6   9 116]]
# Training complete in 0m 49s
# Best val Acc: 0.725904

# %%
plot_loss_with_MyModel(finetuned_MyModel, plot_title = "CNN Model")

# %%
plot_cm_with_MyModel(MyModel_here = finetuned_MyModel, plot_title = "CNN Model")

# %%
torch.save(finetuned_MyModel.model, './model/EarthquakeCNN_finetuned.pth')
